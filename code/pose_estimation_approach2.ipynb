# %%
import json
import cv2
import numpy as np

from dataclasses import dataclass

from PIL import Image
from IPython import display

import os
import shutil

# %%
@dataclass
class Joint:
    x: float
    y: float
    confidence: float
    
    def is_empty(self):
        return self.x == 0 and self.y == 0 and self.confidence == 0

# %%
joint_colours = np.linspace(0, 179, 26)[:-1]
joint_colours = np.array([(round(h), 255, 255) for h in joint_colours]).astype(np.uint8)
joint_colours = joint_colours[np.newaxis, ...]
joint_colours = cv2.cvtColor(joint_colours, cv2.COLOR_HSV2BGR)
joint_colours = joint_colours.squeeze().astype(int)
joint_colours = [tuple([int(x) for x in joint_colour]) for joint_colour in joint_colours]

# %%
# https://github.com/CMU-Perceptual-Computing-Lab/openpose/blob/master/doc/02_output.md

class PoseClassification:
    INVALID: str = "Invalid"
    HEAD_ONLY: str = "Head Only"
    HALF_BODY: str = "Half Body"
    FULL_BODY_STANDING: str = "Full Body Standing"
    FULL_BODY_SITTING: str = "Full Body Sitting"
    OTHER: str = "Other"
    EMPTY: str = "Empty"
    Y_OTHER: str = "Y Other"
    
@dataclass
class PoseKeypoints:
    nose: Joint
    neck: Joint
    right_shoulder: Joint
    right_elbow: Joint
    right_wrist: Joint
    left_shoulder: Joint
    left_elbow: Joint
    left_wrist: Joint
    mid_hip: Joint
    right_hip: Joint
    right_knee: Joint
    right_ankle: Joint
    left_hip: Joint
    left_knee: Joint
    left_ankle: Joint
    right_eye: Joint
    left_eye: Joint
    right_ear: Joint
    left_ear: Joint
    left_big_toe: Joint
    left_small_toe: Joint
    left_heel: Joint
    right_big_toe: Joint
    right_small_toe: Joint
    right_heel: Joint
    
    def get_empty_points(self):
        return {joint_name: getattr(self, joint_name) for joint_name in self.__annotations__.keys() if getattr(self, joint_name).is_empty()}
    
    def overlay_pose(self, frame):
        mapping = list(PoseKeypoints.__dict__["__annotations__"].keys())
        pose_overlayed_frame = frame.copy()
        height, width, channels = pose_overlayed_frame.shape

        for i, joint_name in enumerate(self.__annotations__.keys()):
            joint = getattr(self, joint_name)

            if joint.is_empty(): 
                continue

            cv2.circle(pose_overlayed_frame, (round(joint.x * width), round(joint.y * height)), radius=1, color=joint_colours[i], thickness=2)
            cv2.putText(pose_overlayed_frame, mapping[i], (round(joint.x * width), round(joint.y * (height - 0.02))), cv2.FONT_HERSHEY_SIMPLEX, 0.5, joint_colours[i], 1, cv2.LINE_AA)
        
        return pose_overlayed_frame

    def classify(self):
        # Note that values close to the top of the image are nearer to 0 and those at the bottom are nearer to 1
        empties = self.get_empty_points()

        # Check for disformed pose (i.e. without enough info to classify)
        if len(empties) > 20:
            return PoseClassification.EMPTY
        
        # Check that they are upright
        mid_hip_y = -self.mid_hip.y
        nose_y = -self.nose.y
        neck_y = -self.neck.y

        if (nose_y < neck_y and nose_y != 0 and neck_y != 0) or (neck_y < mid_hip_y and mid_hip_y != 0 and neck_y != 0):
            return PoseClassification.Y_OTHER
        
        # Check for full body
        # Potentially allow for less to be visible like the bottom of the feet?
        
        empty_key_set = set(empties.keys())
        allowed_empty_keys = set(["left_big_toe", "left_small_toe", "left_heel", "right_big_toe", "right_small_toe", "right_heel"])
        feet_excluded_empties = empty_key_set - allowed_empty_keys
        
        print(feet_excluded_empties)
        
        if len(empties) < 2 or len(feet_excluded_empties) == 0:
            right_hip_y = -self.right_hip.y
            left_hip_y = -self.left_hip.y
            right_knee_y = -self.right_knee.y
            left_knee_y = -self.left_knee.y
            right_ankle_y = -self.right_ankle.y
            left_ankle_y = -self.left_ankle.y
            
            right_ratio = (right_hip_y - right_knee_y) / (right_knee_y - right_ankle_y)
            left_ratio = (left_hip_y - left_knee_y) / (left_knee_y - left_ankle_y)
            
            print(left_ratio, right_ratio)
            
            left_diff = left_hip_y - left_knee_y
            right_diff = right_hip_y - left_knee_y
            
            # For a standing person, left_hip_y > left_knee_y <=> left_diff > 0
            # For a sitting person left_hip_y ~= or < left_knee_y so left_diff ~= or < 0
            # These values use normalised distances making this a bit simpler
            
            print(left_diff, right_diff)
            
            # if left_diff < 0.05 and right_diff < 0.05:
            #     # Approx equal or negative so probably sitting
            #     return PoseClassification.FULL_BODY_SITTING
            
            if left_ratio < 0.65 or right_ratio < 0.65:
                return PoseClassification.FULL_BODY_SITTING
            
            if left_diff > 0.05 and right_diff > 0.05:
                # Both in normal positions
                return PoseClassification.FULL_BODY_STANDING
            
            # Other
            return PoseClassification.OTHER
    
        if not self.right_shoulder.is_empty() and not self.neck.is_empty() and not self.left_shoulder.is_empty() and not self.right_elbow.is_empty() and not self.left_elbow.is_empty():
            return PoseClassification.HALF_BODY
        
        if not self.right_ear.is_empty() and not self.right_eye.is_empty() and not self.nose.is_empty() and not self.left_eye.is_empty() and not self.left_ear.is_empty():
            return PoseClassification.HEAD_ONLY
                
        return PoseClassification.INVALID
    
    @staticmethod
    def load_keypoints(raw_kps):
        mapping = list(PoseKeypoints.__dict__["__annotations__"].keys())
        points_as_dict = {part: Joint(raw_kps[3 * i], raw_kps[3 * i + 1], raw_kps[3 * i + 2]) for i, part in enumerate(mapping)}
        return PoseKeypoints(**points_as_dict)

# %%
in_frame_folder = "./output/segmented/Train/Game"
in_pose_folder = "./output/segmented/Train/Game/openpose_out_normalised"
out_folder = "./output/pose_classified"

# %%
file_names = []

for file in os.listdir(in_frame_folder):
    path = f"{in_frame_folder}/{file}"
    
    if not os.path.isfile(path):
        continue
        
    file_names.append(''.join(file.split(".")[:-1]))

len(file_names)
# Out:
# 135

# %%
for file in file_names:
    frame_loc = f"{in_frame_folder}/{file}.jpg"
    keypoints_loc = f"{in_pose_folder}/{file}_keypoints.json"
    
    with open(keypoints_loc, "r") as fp:
        raw_data = json.load(fp)
    
    if len(raw_data["people"]) != 1:
        # print(frame_loc)
        continue
    
    print(frame_loc)
    
    kps = raw_data["people"][0]["pose_keypoints_2d"]
    pose = PoseKeypoints.load_keypoints(kps)
    
    classification = pose.classify()
    save_loc = f"{out_folder}/{classification}/{file}.jpg"
    
    in_frame = cv2.imread(frame_loc)
    out_frame = pose.overlay_pose(in_frame)
    
    print(classification)
    
    cv2.imwrite(save_loc, out_frame)
# Out:
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00001_0.jpg
# set()
# 0.8257854615402881 1.0739826496820466
# 0.208638 0.21443
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00001_1.jpg
# {'left_ear', 'left_ankle', 'left_knee', 'right_knee', 'right_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00009_0.jpg
# {'mid_hip', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00017_0.jpg
# {'mid_hip', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'left_wrist', 'left_elbow', 'left_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00025_0.jpg
# {'mid_hip', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00033_0.jpg
# set()
# 0.47451712506291854 0.40145667517645295
# 0.12632500000000002 0.10706400000000005
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00041_0.jpg
# set()
# 0.8051447035552792 0.4312761309431276
# 0.17218100000000003 0.16104400000000008
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00049_0.jpg
# set()
# 0.6413067019080745 0.4428476656776679
# 0.14509499999999997 0.133903
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00057_0.jpg
# {'right_ankle', 'left_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00065_0.jpg
# {'left_ankle', 'right_elbow', 'right_wrist', 'right_knee', 'right_ankle'}
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00065_1.jpg
# {'nose', 'left_ankle', 'left_eye', 'left_knee', 'left_hip', 'right_wrist', 'left_wrist', 'right_eye', 'left_elbow', 'mid_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00073_0.jpg
# {'nose', 'left_ankle', 'left_eye', 'right_eye', 'right_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00073_1.jpg
# {'left_ear', 'nose', 'left_ankle', 'left_eye', 'left_knee', 'left_hip', 'right_wrist', 'left_wrist', 'right_eye', 'left_elbow', 'mid_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00081_0.jpg
# {'mid_hip', 'left_ankle', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00089_0.jpg
# {'mid_hip', 'left_ankle', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00097_0.jpg
# {'nose', 'left_eye', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'right_eye', 'right_knee', 'right_ankle'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00105_0.jpg
# {'nose', 'left_ankle', 'left_eye', 'right_elbow', 'left_knee', 'left_hip', 'right_wrist', 'left_wrist', 'right_eye', 'left_elbow', 'mid_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00121_0.jpg
# {'right_ear', 'left_ankle', 'left_knee', 'right_eye', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00121_1.jpg
# {'nose', 'left_eye', 'left_ankle', 'left_knee', 'right_wrist', 'right_eye', 'right_knee', 'right_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00129_0.jpg
# {'right_ear', 'left_ankle', 'left_knee', 'left_wrist', 'right_knee', 'right_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00129_1.jpg
# {'mid_hip', 'left_eye', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'left_wrist', 'left_elbow', 'left_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00137_0.jpg
# {'mid_hip', 'left_ear', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00145_0.jpg
# {'mid_hip', 'right_ear', 'left_ankle', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00153_0.jpg
# {'mid_hip', 'left_ear', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00161_1.jpg
# {'mid_hip', 'left_eye', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'left_wrist', 'left_elbow', 'left_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00169_0.jpg
# {'mid_hip', 'right_ear', 'left_ankle', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00169_1.jpg
# {'mid_hip', 'left_eye', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'left_wrist', 'left_elbow', 'left_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00177_0.jpg
# {'mid_hip', 'left_ankle', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00177_1.jpg
# {'nose', 'left_ankle', 'left_eye', 'right_elbow', 'left_knee', 'left_hip', 'right_wrist', 'left_wrist', 'right_eye', 'left_elbow', 'mid_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00185_0.jpg
# {'mid_hip', 'left_ear', 'left_ankle', 'left_knee', 'right_wrist', 'left_wrist', 'left_elbow', 'left_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00193_0.jpg
# {'right_ear', 'left_ankle', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00201_0.jpg
# {'mid_hip', 'left_ear', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'left_wrist', 'left_elbow', 'left_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00209_0.jpg
# set()
# 0.9315304899660757 1.0380157303266386
# 0.22076900000000005 0.22076600000000002
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00209_1.jpg
# {'right_wrist', 'right_ear'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00217_0.jpg
# {'right_ear'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00225_0.jpg
# {'nose', 'left_ankle', 'right_ear', 'left_eye', 'right_eye', 'right_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00233_0.jpg
# {'right_ear', 'left_ankle', 'right_elbow', 'right_wrist', 'right_eye', 'right_ankle'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00233_1.jpg
# {'nose', 'left_eye', 'left_ankle', 'left_knee', 'left_wrist', 'right_eye', 'right_knee', 'right_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00241_0.jpg
# {'mid_hip', 'nose', 'left_eye', 'left_ankle', 'left_knee', 'right_wrist', 'left_wrist', 'right_eye', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00249_0.jpg
# {'nose', 'left_eye', 'left_ankle', 'left_knee', 'right_eye', 'right_knee', 'right_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00249_1.jpg
# {'right_ankle', 'left_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00257_0.jpg
# {'right_eye', 'right_ankle', 'left_ankle', 'right_ear'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00257_1.jpg
# {'left_ear', 'right_ankle', 'left_ankle', 'left_eye'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00265_1.jpg
# {'mid_hip', 'right_ear', 'left_ankle', 'right_elbow', 'left_knee', 'right_shoulder', 'right_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00265_2.jpg
# {'mid_hip', 'left_ankle', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00273_0.jpg
# set()
# 1.1103890222363113 1.0131897069820577
# 0.245185 0.258845
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00273_1.jpg
# set()
# 0.9724508769284886 1.0143057579191617
# 0.19350799999999996 0.19343599999999994
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00281_0.jpg
# {'mid_hip', 'left_ear', 'left_eye', 'left_ankle', 'right_elbow', 'left_knee', 'right_shoulder', 'right_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00289_0.jpg
# {'right_ear', 'left_ankle', 'left_knee', 'right_wrist', 'right_knee', 'left_hip', 'right_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00297_0.jpg
# {'mid_hip', 'left_ankle', 'left_knee', 'right_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00305_0.jpg
# {'nose', 'left_ankle', 'right_ear', 'right_elbow', 'left_knee', 'left_hip', 'right_shoulder', 'left_wrist', 'right_wrist', 'right_eye', 'right_knee', 'mid_hip', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00305_1.jpg
# {'left_ankle', 'left_knee', 'left_wrist', 'right_knee', 'right_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00313_0.jpg
# Empty
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00313_1.jpg
# {'left_ankle', 'left_knee', 'left_wrist', 'right_knee', 'right_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00321_0.jpg
# {'right_ankle', 'left_knee', 'right_knee', 'left_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00321_1.jpg
# Empty
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00329_0.jpg
# {'right_ankle', 'left_knee', 'right_knee', 'left_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00329_1.jpg
# {'nose', 'left_ankle', 'right_ear', 'right_elbow', 'left_knee', 'left_hip', 'right_shoulder', 'left_wrist', 'right_wrist', 'right_eye', 'right_knee', 'mid_hip', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00003_2.jpg
# {'mid_hip', 'left_ankle', 'left_knee', 'left_wrist', 'right_knee', 'left_hip', 'left_elbow', 'right_ankle', 'right_hip'}
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00003_4.jpg
# {'right_ear', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'right_knee', 'right_ankle'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00011_1.jpg
# {'left_ankle', 'right_ear', 'right_elbow', 'right_wrist', 'right_eye'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00011_4.jpg
# {'left_ankle', 'right_ear', 'left_shoulder', 'left_knee', 'left_wrist', 'right_knee', 'left_hip', 'left_elbow', 'right_ankle'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00019_0.jpg
# set()
# 7.621875938469777 0.9999431124491842
# 0.22842000000000007 0.21755700000000006
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00019_1.jpg
# {'right_ankle', 'left_ankle', 'right_ear'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00019_2.jpg
# {'left_ear'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00019_4.jpg
# {'mid_hip', 'left_ear', 'right_ear', 'left_ankle', 'right_elbow', 'left_knee', 'right_shoulder', 'right_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00019_5.jpg
# {'right_ankle', 'left_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00027_1.jpg
# {'mid_hip', 'right_ear', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00027_2.jpg
# {'left_ankle', 'left_knee', 'left_wrist', 'left_elbow', 'right_knee', 'right_ankle'}
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00027_3.jpg
# Empty
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00035_1.jpg
# {'left_ear', 'right_ankle', 'left_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00035_2.jpg
# {'mid_hip', 'left_ear', 'left_ankle', 'left_knee', 'left_wrist', 'right_knee', 'left_hip', 'left_elbow', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00035_3.jpg
# {'mid_hip', 'left_ankle', 'left_knee', 'left_wrist', 'right_knee', 'left_hip', 'left_elbow', 'right_ankle', 'right_hip'}
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00043_1.jpg
# {'mid_hip', 'right_ear', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'left_wrist', 'right_eye', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00043_2.jpg
# {'left_wrist', 'left_elbow'}
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00043_3.jpg
# {'mid_hip', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00051_0.jpg
# {'right_ankle', 'left_ankle', 'right_ear'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00051_1.jpg
# {'right_ankle', 'left_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00051_2.jpg
# {'right_eye'}
# 1.1136364672364674 1.0248109130199894
# 0.24430400000000002 0.24704199999999998
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00051_3.jpg
# {'left_ankle', 'right_elbow', 'left_knee', 'left_hip', 'right_shoulder', 'right_wrist', 'left_wrist', 'neck', 'left_elbow', 'mid_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00051_4.jpg
# {'left_ear', 'right_ankle', 'left_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00059_0.jpg
# {'mid_hip', 'nose', 'left_eye', 'left_ankle', 'left_knee', 'right_wrist', 'left_wrist', 'right_eye', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00059_1.jpg
# {'left_ear', 'left_ankle', 'left_knee', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00067_0.jpg
# {'mid_hip', 'left_eye', 'left_ankle', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00067_1.jpg
# {'left_ear', 'left_ankle', 'left_knee', 'left_wrist', 'right_knee', 'right_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00075_1.jpg
# {'mid_hip', 'left_ear', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'left_wrist', 'left_elbow', 'left_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00075_2.jpg
# set()
# 0.9233916183597833 1.038958508570586
# 0.19433699999999998 0.19431299999999996
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00075_3.jpg
# {'left_wrist', 'right_ankle', 'left_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00075_4.jpg
# {'right_wrist', 'right_elbow', 'left_wrist', 'right_eye'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00083_1.jpg
# {'left_ear', 'left_ankle', 'left_eye', 'right_elbow', 'left_knee', 'left_hip', 'right_wrist', 'left_wrist', 'left_elbow', 'mid_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00083_2.jpg
# set()
# 0.9852271795292378 1.013129156664437
# 0.192206 0.19219600000000003
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00091_0.jpg
# {'mid_hip', 'left_ankle', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00091_1.jpg
# {'left_ankle', 'right_ear', 'right_elbow', 'left_knee', 'left_hip', 'right_wrist', 'left_wrist', 'right_eye', 'left_elbow', 'mid_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00099_0.jpg
# {'mid_hip', 'left_ear', 'left_ankle', 'left_knee', 'right_wrist', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00099_1.jpg
# {'mid_hip', 'right_ear', 'left_ankle', 'right_elbow', 'left_knee', 'right_wrist', 'left_wrist', 'right_eye', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00107_1.jpg
# {'right_ear', 'left_ankle', 'left_knee', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00107_2.jpg
# {'mid_hip', 'left_ear', 'left_ankle', 'left_knee', 'right_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00115_0.jpg
# {'left_ankle', 'right_ear', 'left_knee', 'right_knee', 'right_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00115_2.jpg
# {'mid_hip', 'left_ear', 'left_eye', 'left_ankle', 'left_knee', 'right_wrist', 'left_wrist', 'left_elbow', 'left_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Invalid
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00123_0.jpg
# {'right_ankle', 'left_knee', 'right_knee', 'left_ankle'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00123_1.jpg
# {'mid_hip', 'right_ear', 'left_ankle', 'left_knee', 'left_wrist', 'right_knee', 'left_hip', 'right_ankle', 'right_hip'}
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_02_00123_2.jpg
# {'mid_hip', 'left_ear', 'left_ankle', 'left_knee', 'right_wrist', 'left_wrist', 'left_elbow', 'left_hip', 'right_knee', 'right_ankle', 'right_hip'}
# Invalid
