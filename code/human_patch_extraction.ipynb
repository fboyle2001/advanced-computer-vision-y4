# %%
import random
import time
import os

import cv2
import numpy as np

import torch
import torchvision
from PIL import Image
from IPython import display

import torchvision.models
from torchvision.transforms import transforms

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
if (torch.cuda.device_count()>0):
    print(torch.cuda.get_device_name(0))
# Out:
# cuda:0
# NVIDIA GeForce GTX 1080

# %%
model = torchvision.models.detection.maskrcnn_resnet50_fpn_v2(weights="DEFAULT")
model.to(device).eval()
;
# Out:
# ''

# %%
img_directory = "./frames/Train/Movie"
output_directory = "./output/segmented/Train/Movie"
batch_size = 4

# %%
file_names = [file_name for file_name in os.listdir(img_directory) if file_name.endswith(".jpg")]
len(file_names)
# Out:
# 4665

# %%
file_names[:10]
# Out:
# ['Train_Movie_01_00001.jpg',
#  'Train_Movie_01_00002.jpg',
#  'Train_Movie_01_00003.jpg',
#  'Train_Movie_01_00004.jpg',
#  'Train_Movie_01_00005.jpg',
#  'Train_Movie_01_00006.jpg',
#  'Train_Movie_01_00007.jpg',
#  'Train_Movie_01_00008.jpg',
#  'Train_Movie_01_00009.jpg',
#  'Train_Movie_01_00010.jpg']

# %%
transform = transforms.Compose([
    transforms.ToTensor()
])

def batch_loader(directory, file_names, batch_size):
    for i in range(len(file_names) // batch_size + 1):
        selected = []
        start_idx = batch_size * i
        limit_idx = batch_size * (i + 1)
        
        if limit_idx > len(file_names):
            selected = file_names[start_idx:]
        else:
            selected = file_names[start_idx:limit_idx]
            
        if len(selected) == 0:
            break
        
        output_files = []
        raw_frames = []
        usable_frames = []
        
        for file_name in selected:
            output_files.append(f"{output_directory}/Segmented_{file_name.split('.')[0]}")
            input_file = f"{directory}/{file_name}"
            raw_frame = cv2.imread(input_file, cv2.IMREAD_COLOR)
            raw_frames.append(raw_frame)
            
            usable_frame = cv2.cvtColor(raw_frame, cv2.COLOR_BGR2RGB)
            usable_frame = transform(usable_frame)
            usable_frames.append(usable_frame)
        
        stacked_frames = torch.stack(usable_frames).to(device)
        yield stacked_frames, raw_frames, output_files
            
batch_generator = batch_loader(img_directory, file_names, batch_size)

# %%
# The 91 COCO class names
coco_names = ['__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table', 'N/A', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# Generate a set of color for drawing different classes
COLORS = np.random.uniform(0, 255, size=(len(coco_names), 3))

threshold = 0.965

# %%
def process_maskrcnn_output(output, frame, save_loc, threshold):
    scores = list(output['scores'].detach().cpu().numpy()) # Get scores
    thresholded_objects = [scores.index(i) for i in scores if i > threshold]
    thresholded_objects_count = len(thresholded_objects)
    masks = (output['masks']>0.5).squeeze().detach().cpu().numpy()
    masks = masks[:thresholded_objects_count]
    boxes = [[(i[0], i[1]), (i[2], i[3])]  for i in output['boxes'].detach().cpu()]
    boxes = boxes[:thresholded_objects_count]
    labels = [coco_names[i] for i in output['labels']][:thresholded_objects_count]
    
    for i, label in enumerate(labels):
        if label != "person":
            continue
            
        
        out_frame = np.array(frame.copy())
        out_frame = out_frame[int(boxes[i][0][1]):int(boxes[i][1][1]), int(boxes[i][0][0]):int(boxes[i][1][0])]
        
        cv2.imwrite(f"{save_loc}_{i}.jpg", out_frame)
        
    
    return
    
    print(scores) # The scores are sorted from largest to the shortest
    thresholded_objects = [scores.index(i) for i in scores if i > threshold] # Get an index for the objects having the scores > a threshold of 0.965
    thresholded_objects_count = len(thresholded_objects) # Total objects having scores > threshold
    masks = (output['masks']>0.5).squeeze().detach().cpu().numpy() # Get the segmentation masks
    masks = masks[:thresholded_objects_count] # Discard masks for objects that are below threshold by only taking the beginning of the list
    boxes = [[(i[0], i[1]), (i[2], i[3])]  for i in output['boxes'].detach().cpu()] # Get the bounding boxes, in (x1, y1), (x2, y2) format
    boxes = boxes[:thresholded_objects_count] # Discard bounding boxes for objects that are below threshold by only taking the beginning of the list
    labels = [coco_names[i] for i in output['labels']] # Get the classes labels
    
    out_frame = np.array(frame.copy())
    
    # Draw the segmentation masks with the text labels
    for i in range(len(masks)): # For all detected objects with score > threshold
        color = COLORS[random.randrange(0, len(COLORS))] # Pick a random color
        red_map = np.zeros_like(masks[i]).astype(np.uint8) # Initialize an empty mask for each of the RGB channels
        green_map = np.zeros_like(masks[i]).astype(np.uint8)
        blue_map = np.zeros_like(masks[i]).astype(np.uint8)
        red_map[masks[i] == 1], green_map[masks[i] == 1], blue_map[masks[i] == 1] = color # Set the color of the masked pixels
        segmentation_map = np.stack([red_map, green_map, blue_map], axis=2) # Combine the three channels of the mask
        cv2.addWeighted(out_frame, 1.0, segmentation_map, 0.6, 0.0, out_frame) # Apply the mask onto the image
        cv2.rectangle(out_frame, (int(boxes[i][0][0]),int(boxes[i][0][1])), (int(boxes[i][1][0]),int(boxes[i][1][1])), color, 2) # Draw the bounding boxes
        cv2.putText(out_frame , labels[i], (int(boxes[i][0][0]), int(boxes[i][0][1])-10), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2, cv2.LINE_AA) # Draw the class label as text
    
    cv2.imwrite(save_loc, out_frame)

# %%
batch_generator = batch_loader(img_directory, file_names, batch_size)

for i, (batch, raw_frames, output_files) in enumerate(batch_generator):
    print(f"Batch {i}, count: {i * batch_size} / {len(file_names)}")
    with torch.no_grad():
        outputs = model(batch)
    
    for output, frame, output_file in zip(outputs, raw_frames, output_files):
        process_maskrcnn_output(output, frame, output_file, threshold)
# Out:
# Batch 0, count: 0 / 4665
# Batch 1, count: 4 / 4665
# Batch 2, count: 8 / 4665
# Batch 3, count: 12 / 4665
# Batch 4, count: 16 / 4665
# Batch 5, count: 20 / 4665
# Batch 6, count: 24 / 4665
# Batch 7, count: 28 / 4665
# Batch 8, count: 32 / 4665
# Batch 9, count: 36 / 4665
# Batch 10, count: 40 / 4665
# Batch 11, count: 44 / 4665
# Batch 12, count: 48 / 4665
# Batch 13, count: 52 / 4665
# Batch 14, count: 56 / 4665
# Batch 15, count: 60 / 4665
# Batch 16, count: 64 / 4665
# Batch 17, count: 68 / 4665
# Batch 18, count: 72 / 4665
# Batch 19, count: 76 / 4665
# Batch 20, count: 80 / 4665
# Batch 21, count: 84 / 4665
# Batch 22, count: 88 / 4665
# Batch 23, count: 92 / 4665
# Batch 24, count: 96 / 4665
# Batch 25, count: 100 / 4665
# Batch 26, count: 104 / 4665
# Batch 27, count: 108 / 4665
# Batch 28, count: 112 / 4665
# Batch 29, count: 116 / 4665
# Batch 30, count: 120 / 4665
# Batch 31, count: 124 / 4665
# Batch 32, count: 128 / 4665
# Batch 33, count: 132 / 4665
# Batch 34, count: 136 / 4665
# Batch 35, count: 140 / 4665
# Batch 36, count: 144 / 4665
# Batch 37, count: 148 / 4665
# Batch 38, count: 152 / 4665
# Batch 39, count: 156 / 4665
# Batch 40, count: 160 / 4665
# Batch 41, count: 164 / 4665
# Batch 42, count: 168 / 4665
# Batch 43, count: 172 / 4665
# Batch 44, count: 176 / 4665
# Batch 45, count: 180 / 4665
# Batch 46, count: 184 / 4665
# Batch 47, count: 188 / 4665
# Batch 48, count: 192 / 4665
# Batch 49, count: 196 / 4665
# Batch 50, count: 200 / 4665
# Batch 51, count: 204 / 4665
# Batch 52, count: 208 / 4665
# Batch 53, count: 212 / 4665
# Batch 54, count: 216 / 4665
# Batch 55, count: 220 / 4665
# Batch 56, count: 224 / 4665
# Batch 57, count: 228 / 4665
# Batch 58, count: 232 / 4665
# Batch 59, count: 236 / 4665
# Batch 60, count: 240 / 4665
# Batch 61, count: 244 / 4665
# Batch 62, count: 248 / 4665
# Batch 63, count: 252 / 4665
# Batch 64, count: 256 / 4665
# Batch 65, count: 260 / 4665
# Batch 66, count: 264 / 4665
# Batch 67, count: 268 / 4665
# Batch 68, count: 272 / 4665
# Batch 69, count: 276 / 4665
# Batch 70, count: 280 / 4665
# Batch 71, count: 284 / 4665
# Batch 72, count: 288 / 4665
# Batch 73, count: 292 / 4665
# Batch 74, count: 296 / 4665
# Batch 75, count: 300 / 4665
# Batch 76, count: 304 / 4665
# Batch 77, count: 308 / 4665
# Batch 78, count: 312 / 4665
# Batch 79, count: 316 / 4665
# Batch 80, count: 320 / 4665
# Batch 81, count: 324 / 4665
# Batch 82, count: 328 / 4665
# Batch 83, count: 332 / 4665
# Batch 84, count: 336 / 4665
# Batch 85, count: 340 / 4665
# Batch 86, count: 344 / 4665
# Batch 87, count: 348 / 4665
# Batch 88, count: 352 / 4665
# Batch 89, count: 356 / 4665
# Batch 90, count: 360 / 4665
# Batch 91, count: 364 / 4665
# Batch 92, count: 368 / 4665
# Batch 93, count: 372 / 4665
# Batch 94, count: 376 / 4665
# Batch 95, count: 380 / 4665
# Batch 96, count: 384 / 4665
# Batch 97, count: 388 / 4665
# Batch 98, count: 392 / 4665
# Batch 99, count: 396 / 4665
# Batch 100, count: 400 / 4665
# Batch 101, count: 404 / 4665
# Batch 102, count: 408 / 4665
# Batch 103, count: 412 / 4665
# Batch 104, count: 416 / 4665
# Batch 105, count: 420 / 4665
# Batch 106, count: 424 / 4665
# Batch 107, count: 428 / 4665
# Batch 108, count: 432 / 4665
# Batch 109, count: 436 / 4665
# Batch 110, count: 440 / 4665
# Batch 111, count: 444 / 4665
# Batch 112, count: 448 / 4665
# Batch 113, count: 452 / 4665
# Batch 114, count: 456 / 4665
# Batch 115, count: 460 / 4665
# Batch 116, count: 464 / 4665
# Batch 117, count: 468 / 4665
# Batch 118, count: 472 / 4665
# Batch 119, count: 476 / 4665
# Batch 120, count: 480 / 4665
# Batch 121, count: 484 / 4665
# Batch 122, count: 488 / 4665
# Batch 123, count: 492 / 4665
# Batch 124, count: 496 / 4665
# Batch 125, count: 500 / 4665
# Batch 126, count: 504 / 4665
# Batch 127, count: 508 / 4665
# Batch 128, count: 512 / 4665
# Batch 129, count: 516 / 4665
# Batch 130, count: 520 / 4665
# Batch 131, count: 524 / 4665
# Batch 132, count: 528 / 4665
# Batch 133, count: 532 / 4665
# Batch 134, count: 536 / 4665
# Batch 135, count: 540 / 4665
# Batch 136, count: 544 / 4665
# Batch 137, count: 548 / 4665
# Batch 138, count: 552 / 4665
# Batch 139, count: 556 / 4665
# Batch 140, count: 560 / 4665
# Batch 141, count: 564 / 4665
# Batch 142, count: 568 / 4665
# Batch 143, count: 572 / 4665
# Batch 144, count: 576 / 4665
# Batch 145, count: 580 / 4665
# Batch 146, count: 584 / 4665
# Batch 147, count: 588 / 4665
# Batch 148, count: 592 / 4665
# Batch 149, count: 596 / 4665
# Batch 150, count: 600 / 4665
# Batch 151, count: 604 / 4665
# Batch 152, count: 608 / 4665
# Batch 153, count: 612 / 4665
# Batch 154, count: 616 / 4665
# Batch 155, count: 620 / 4665
# Batch 156, count: 624 / 4665
# Batch 157, count: 628 / 4665
# Batch 158, count: 632 / 4665
# Batch 159, count: 636 / 4665
# Batch 160, count: 640 / 4665
# Batch 161, count: 644 / 4665
# Batch 162, count: 648 / 4665
# Batch 163, count: 652 / 4665
# Batch 164, count: 656 / 4665
# Batch 165, count: 660 / 4665
# Batch 166, count: 664 / 4665
# Batch 167, count: 668 / 4665
# Batch 168, count: 672 / 4665
# Batch 169, count: 676 / 4665
# Batch 170, count: 680 / 4665
# Batch 171, count: 684 / 4665
# Batch 172, count: 688 / 4665
# Batch 173, count: 692 / 4665
# Batch 174, count: 696 / 4665
# Batch 175, count: 700 / 4665
# Batch 176, count: 704 / 4665
# Batch 177, count: 708 / 4665
# Batch 178, count: 712 / 4665
# Batch 179, count: 716 / 4665
# Batch 180, count: 720 / 4665
# Batch 181, count: 724 / 4665
# Batch 182, count: 728 / 4665
# Batch 183, count: 732 / 4665
# Batch 184, count: 736 / 4665
# Batch 185, count: 740 / 4665
# Batch 186, count: 744 / 4665
# Batch 187, count: 748 / 4665
# Batch 188, count: 752 / 4665
# Batch 189, count: 756 / 4665
# Batch 190, count: 760 / 4665
# Batch 191, count: 764 / 4665
# Batch 192, count: 768 / 4665
# Batch 193, count: 772 / 4665
# Batch 194, count: 776 / 4665
# Batch 195, count: 780 / 4665
# Batch 196, count: 784 / 4665
# Batch 197, count: 788 / 4665
# Batch 198, count: 792 / 4665
# Batch 199, count: 796 / 4665
# Batch 200, count: 800 / 4665
# Batch 201, count: 804 / 4665
# Batch 202, count: 808 / 4665
# Batch 203, count: 812 / 4665
# Batch 204, count: 816 / 4665
# Batch 205, count: 820 / 4665
# Batch 206, count: 824 / 4665
# Batch 207, count: 828 / 4665
# Batch 208, count: 832 / 4665
# Batch 209, count: 836 / 4665
# Batch 210, count: 840 / 4665
# Batch 211, count: 844 / 4665
# Batch 212, count: 848 / 4665
# Batch 213, count: 852 / 4665
# Batch 214, count: 856 / 4665
# Batch 215, count: 860 / 4665
# Batch 216, count: 864 / 4665
# Batch 217, count: 868 / 4665
# Batch 218, count: 872 / 4665
# Batch 219, count: 876 / 4665
# Batch 220, count: 880 / 4665
# Batch 221, count: 884 / 4665
# Batch 222, count: 888 / 4665
# Batch 223, count: 892 / 4665
# Batch 224, count: 896 / 4665
# Batch 225, count: 900 / 4665
# Batch 226, count: 904 / 4665
# Batch 227, count: 908 / 4665
# Batch 228, count: 912 / 4665
# Batch 229, count: 916 / 4665
# Batch 230, count: 920 / 4665
# Batch 231, count: 924 / 4665
# Batch 232, count: 928 / 4665
# Batch 233, count: 932 / 4665
# Batch 234, count: 936 / 4665
# Batch 235, count: 940 / 4665
# Batch 236, count: 944 / 4665
# Batch 237, count: 948 / 4665
# Batch 238, count: 952 / 4665
# Batch 239, count: 956 / 4665
# Batch 240, count: 960 / 4665
# Batch 241, count: 964 / 4665
# Batch 242, count: 968 / 4665
# Batch 243, count: 972 / 4665
# Batch 244, count: 976 / 4665
# Batch 245, count: 980 / 4665
# Batch 246, count: 984 / 4665
# Batch 247, count: 988 / 4665
# Batch 248, count: 992 / 4665
# Batch 249, count: 996 / 4665
# Batch 250, count: 1000 / 4665
# Batch 251, count: 1004 / 4665
# Batch 252, count: 1008 / 4665
# Batch 253, count: 1012 / 4665
# Batch 254, count: 1016 / 4665
# Batch 255, count: 1020 / 4665
# Batch 256, count: 1024 / 4665
# Batch 257, count: 1028 / 4665
# Batch 258, count: 1032 / 4665
# Batch 259, count: 1036 / 4665
# Batch 260, count: 1040 / 4665
# Batch 261, count: 1044 / 4665
# Batch 262, count: 1048 / 4665
# Batch 263, count: 1052 / 4665
# Batch 264, count: 1056 / 4665
# Batch 265, count: 1060 / 4665
# Batch 266, count: 1064 / 4665
# Batch 267, count: 1068 / 4665
# Batch 268, count: 1072 / 4665
# Batch 269, count: 1076 / 4665
# Batch 270, count: 1080 / 4665
# Batch 271, count: 1084 / 4665
# Batch 272, count: 1088 / 4665
# Batch 273, count: 1092 / 4665
# Batch 274, count: 1096 / 4665
# Batch 275, count: 1100 / 4665
# Batch 276, count: 1104 / 4665
# Batch 277, count: 1108 / 4665
# Batch 278, count: 1112 / 4665
# Batch 279, count: 1116 / 4665
# Batch 280, count: 1120 / 4665
# Batch 281, count: 1124 / 4665
# Batch 282, count: 1128 / 4665
# Batch 283, count: 1132 / 4665
# Batch 284, count: 1136 / 4665
# Batch 285, count: 1140 / 4665
# Batch 286, count: 1144 / 4665
# Batch 287, count: 1148 / 4665
# Batch 288, count: 1152 / 4665
# Batch 289, count: 1156 / 4665
# Batch 290, count: 1160 / 4665
# Batch 291, count: 1164 / 4665
# Batch 292, count: 1168 / 4665
# Batch 293, count: 1172 / 4665
# Batch 294, count: 1176 / 4665
# Batch 295, count: 1180 / 4665
# Batch 296, count: 1184 / 4665
# Batch 297, count: 1188 / 4665
# Batch 298, count: 1192 / 4665
# Batch 299, count: 1196 / 4665
# Batch 300, count: 1200 / 4665
# Batch 301, count: 1204 / 4665
# Batch 302, count: 1208 / 4665
# Batch 303, count: 1212 / 4665
# Batch 304, count: 1216 / 4665
# Batch 305, count: 1220 / 4665
# Batch 306, count: 1224 / 4665
# Batch 307, count: 1228 / 4665
# Batch 308, count: 1232 / 4665
# Batch 309, count: 1236 / 4665
# Batch 310, count: 1240 / 4665
# Batch 311, count: 1244 / 4665
# Batch 312, count: 1248 / 4665
# Batch 313, count: 1252 / 4665
# Batch 314, count: 1256 / 4665
# Batch 315, count: 1260 / 4665
# Batch 316, count: 1264 / 4665
# Batch 317, count: 1268 / 4665
# Batch 318, count: 1272 / 4665
# Batch 319, count: 1276 / 4665
# Batch 320, count: 1280 / 4665
# Batch 321, count: 1284 / 4665
# Batch 322, count: 1288 / 4665
# Batch 323, count: 1292 / 4665
# Batch 324, count: 1296 / 4665
# Batch 325, count: 1300 / 4665
# Batch 326, count: 1304 / 4665
# Batch 327, count: 1308 / 4665
# Batch 328, count: 1312 / 4665
# Batch 329, count: 1316 / 4665
# Batch 330, count: 1320 / 4665
# Batch 331, count: 1324 / 4665
# Batch 332, count: 1328 / 4665
# Batch 333, count: 1332 / 4665
# Batch 334, count: 1336 / 4665
# Batch 335, count: 1340 / 4665
# Batch 336, count: 1344 / 4665
# Batch 337, count: 1348 / 4665
# Batch 338, count: 1352 / 4665
# Batch 339, count: 1356 / 4665
# Batch 340, count: 1360 / 4665
# Batch 341, count: 1364 / 4665
# Batch 342, count: 1368 / 4665
# Batch 343, count: 1372 / 4665
# Batch 344, count: 1376 / 4665
# Batch 345, count: 1380 / 4665
# Batch 346, count: 1384 / 4665
# Batch 347, count: 1388 / 4665
# Batch 348, count: 1392 / 4665
# Batch 349, count: 1396 / 4665
# Batch 350, count: 1400 / 4665
# Batch 351, count: 1404 / 4665
# Batch 352, count: 1408 / 4665
# Batch 353, count: 1412 / 4665
# Batch 354, count: 1416 / 4665
# Batch 355, count: 1420 / 4665
# Batch 356, count: 1424 / 4665
# Batch 357, count: 1428 / 4665
# Batch 358, count: 1432 / 4665
# Batch 359, count: 1436 / 4665
# Batch 360, count: 1440 / 4665
# Batch 361, count: 1444 / 4665
# Batch 362, count: 1448 / 4665
# Batch 363, count: 1452 / 4665
# Batch 364, count: 1456 / 4665
# Batch 365, count: 1460 / 4665
# Batch 366, count: 1464 / 4665
# Batch 367, count: 1468 / 4665
# Batch 368, count: 1472 / 4665
# Batch 369, count: 1476 / 4665
# Batch 370, count: 1480 / 4665
# Batch 371, count: 1484 / 4665
# Batch 372, count: 1488 / 4665
# Batch 373, count: 1492 / 4665
# Batch 374, count: 1496 / 4665
# Batch 375, count: 1500 / 4665
# Batch 376, count: 1504 / 4665
# Batch 377, count: 1508 / 4665
# Batch 378, count: 1512 / 4665
# Batch 379, count: 1516 / 4665
# Batch 380, count: 1520 / 4665
# Batch 381, count: 1524 / 4665
# Batch 382, count: 1528 / 4665
# Batch 383, count: 1532 / 4665
# Batch 384, count: 1536 / 4665
# Batch 385, count: 1540 / 4665
# Batch 386, count: 1544 / 4665
# Batch 387, count: 1548 / 4665
# Batch 388, count: 1552 / 4665
# Batch 389, count: 1556 / 4665
# Batch 390, count: 1560 / 4665
# Batch 391, count: 1564 / 4665
# Batch 392, count: 1568 / 4665
# Batch 393, count: 1572 / 4665
# Batch 394, count: 1576 / 4665
# Batch 395, count: 1580 / 4665
# Batch 396, count: 1584 / 4665
# Batch 397, count: 1588 / 4665
# Batch 398, count: 1592 / 4665
# Batch 399, count: 1596 / 4665
# Batch 400, count: 1600 / 4665
# Batch 401, count: 1604 / 4665
# Batch 402, count: 1608 / 4665
# Batch 403, count: 1612 / 4665
# Batch 404, count: 1616 / 4665
# Batch 405, count: 1620 / 4665
# Batch 406, count: 1624 / 4665
# Batch 407, count: 1628 / 4665
# Batch 408, count: 1632 / 4665
# Batch 409, count: 1636 / 4665
# Batch 410, count: 1640 / 4665
# Batch 411, count: 1644 / 4665
# Batch 412, count: 1648 / 4665
# Batch 413, count: 1652 / 4665
# Batch 414, count: 1656 / 4665
# Batch 415, count: 1660 / 4665
# Batch 416, count: 1664 / 4665
# Batch 417, count: 1668 / 4665
# Batch 418, count: 1672 / 4665
# Batch 419, count: 1676 / 4665
# Batch 420, count: 1680 / 4665
# Batch 421, count: 1684 / 4665
# Batch 422, count: 1688 / 4665
# Batch 423, count: 1692 / 4665
# Batch 424, count: 1696 / 4665
# Batch 425, count: 1700 / 4665
# Batch 426, count: 1704 / 4665
# Batch 427, count: 1708 / 4665
# Batch 428, count: 1712 / 4665
# Batch 429, count: 1716 / 4665
# Batch 430, count: 1720 / 4665
# Batch 431, count: 1724 / 4665
# Batch 432, count: 1728 / 4665
# Batch 433, count: 1732 / 4665
# Batch 434, count: 1736 / 4665
# Batch 435, count: 1740 / 4665
# Batch 436, count: 1744 / 4665
# Batch 437, count: 1748 / 4665
# Batch 438, count: 1752 / 4665
# Batch 439, count: 1756 / 4665
# Batch 440, count: 1760 / 4665
# Batch 441, count: 1764 / 4665
# Batch 442, count: 1768 / 4665
# Batch 443, count: 1772 / 4665
# Batch 444, count: 1776 / 4665
# Batch 445, count: 1780 / 4665
# Batch 446, count: 1784 / 4665
# Batch 447, count: 1788 / 4665
# Batch 448, count: 1792 / 4665
# Batch 449, count: 1796 / 4665
# Batch 450, count: 1800 / 4665
# Batch 451, count: 1804 / 4665
# Batch 452, count: 1808 / 4665
# Batch 453, count: 1812 / 4665
# Batch 454, count: 1816 / 4665
# Batch 455, count: 1820 / 4665
# Batch 456, count: 1824 / 4665
# Batch 457, count: 1828 / 4665
# Batch 458, count: 1832 / 4665
# Batch 459, count: 1836 / 4665
# Batch 460, count: 1840 / 4665
# Batch 461, count: 1844 / 4665
# Batch 462, count: 1848 / 4665
# Batch 463, count: 1852 / 4665
# Batch 464, count: 1856 / 4665
# Batch 465, count: 1860 / 4665
# Batch 466, count: 1864 / 4665
# Batch 467, count: 1868 / 4665
# Batch 468, count: 1872 / 4665
# Batch 469, count: 1876 / 4665
# Batch 470, count: 1880 / 4665
# Batch 471, count: 1884 / 4665
# Batch 472, count: 1888 / 4665
# Batch 473, count: 1892 / 4665
# Batch 474, count: 1896 / 4665
# Batch 475, count: 1900 / 4665
# Batch 476, count: 1904 / 4665
# Batch 477, count: 1908 / 4665
# Batch 478, count: 1912 / 4665
# Batch 479, count: 1916 / 4665
# Batch 480, count: 1920 / 4665
# Batch 481, count: 1924 / 4665
# Batch 482, count: 1928 / 4665
# Batch 483, count: 1932 / 4665
# Batch 484, count: 1936 / 4665
# Batch 485, count: 1940 / 4665
# Batch 486, count: 1944 / 4665
# Batch 487, count: 1948 / 4665
# Batch 488, count: 1952 / 4665
# Batch 489, count: 1956 / 4665
# Batch 490, count: 1960 / 4665
# Batch 491, count: 1964 / 4665
# Batch 492, count: 1968 / 4665
# Batch 493, count: 1972 / 4665
# Batch 494, count: 1976 / 4665
# Batch 495, count: 1980 / 4665
# Batch 496, count: 1984 / 4665
# Batch 497, count: 1988 / 4665
# Batch 498, count: 1992 / 4665
# Batch 499, count: 1996 / 4665
# Batch 500, count: 2000 / 4665
# Batch 501, count: 2004 / 4665
# Batch 502, count: 2008 / 4665
# Batch 503, count: 2012 / 4665
# Batch 504, count: 2016 / 4665
# Batch 505, count: 2020 / 4665
# Batch 506, count: 2024 / 4665
# Batch 507, count: 2028 / 4665
# Batch 508, count: 2032 / 4665
# Batch 509, count: 2036 / 4665
# Batch 510, count: 2040 / 4665
# Batch 511, count: 2044 / 4665
# Batch 512, count: 2048 / 4665
# Batch 513, count: 2052 / 4665
# Batch 514, count: 2056 / 4665
# Batch 515, count: 2060 / 4665
# Batch 516, count: 2064 / 4665
# Batch 517, count: 2068 / 4665
# Batch 518, count: 2072 / 4665
# Batch 519, count: 2076 / 4665
# Batch 520, count: 2080 / 4665
# Batch 521, count: 2084 / 4665
# Batch 522, count: 2088 / 4665
# Batch 523, count: 2092 / 4665
# Batch 524, count: 2096 / 4665
# Batch 525, count: 2100 / 4665
# Batch 526, count: 2104 / 4665
# Batch 527, count: 2108 / 4665
# Batch 528, count: 2112 / 4665
# Batch 529, count: 2116 / 4665
# Batch 530, count: 2120 / 4665
# Batch 531, count: 2124 / 4665
# Batch 532, count: 2128 / 4665
# Batch 533, count: 2132 / 4665
# Batch 534, count: 2136 / 4665
# Batch 535, count: 2140 / 4665
# Batch 536, count: 2144 / 4665
# Batch 537, count: 2148 / 4665
# Batch 538, count: 2152 / 4665
# Batch 539, count: 2156 / 4665
# Batch 540, count: 2160 / 4665
# Batch 541, count: 2164 / 4665
# Batch 542, count: 2168 / 4665
# Batch 543, count: 2172 / 4665
# Batch 544, count: 2176 / 4665
# Batch 545, count: 2180 / 4665
# Batch 546, count: 2184 / 4665
# Batch 547, count: 2188 / 4665
# Batch 548, count: 2192 / 4665
# Batch 549, count: 2196 / 4665
# Batch 550, count: 2200 / 4665
# Batch 551, count: 2204 / 4665
# Batch 552, count: 2208 / 4665
# Batch 553, count: 2212 / 4665
# Batch 554, count: 2216 / 4665
# Batch 555, count: 2220 / 4665
# Batch 556, count: 2224 / 4665
# Batch 557, count: 2228 / 4665
# Batch 558, count: 2232 / 4665
# Batch 559, count: 2236 / 4665
# Batch 560, count: 2240 / 4665
# Batch 561, count: 2244 / 4665
# Batch 562, count: 2248 / 4665
# Batch 563, count: 2252 / 4665
# Batch 564, count: 2256 / 4665
# Batch 565, count: 2260 / 4665
# Batch 566, count: 2264 / 4665
# Batch 567, count: 2268 / 4665
# Batch 568, count: 2272 / 4665
# Batch 569, count: 2276 / 4665
# Batch 570, count: 2280 / 4665
# Batch 571, count: 2284 / 4665
# Batch 572, count: 2288 / 4665
# Batch 573, count: 2292 / 4665
# Batch 574, count: 2296 / 4665
# Batch 575, count: 2300 / 4665
# Batch 576, count: 2304 / 4665
# Batch 577, count: 2308 / 4665
# Batch 578, count: 2312 / 4665
# Batch 579, count: 2316 / 4665
# Batch 580, count: 2320 / 4665
# Batch 581, count: 2324 / 4665
# Batch 582, count: 2328 / 4665
# Batch 583, count: 2332 / 4665
# Batch 584, count: 2336 / 4665
# Batch 585, count: 2340 / 4665
# Batch 586, count: 2344 / 4665
# Batch 587, count: 2348 / 4665
# Batch 588, count: 2352 / 4665
# Batch 589, count: 2356 / 4665
# Batch 590, count: 2360 / 4665
# Batch 591, count: 2364 / 4665
# Batch 592, count: 2368 / 4665
# Batch 593, count: 2372 / 4665
# Batch 594, count: 2376 / 4665
# Batch 595, count: 2380 / 4665
# Batch 596, count: 2384 / 4665
# Batch 597, count: 2388 / 4665
# Batch 598, count: 2392 / 4665
# Batch 599, count: 2396 / 4665
# Batch 600, count: 2400 / 4665
# Batch 601, count: 2404 / 4665
# Batch 602, count: 2408 / 4665
# Batch 603, count: 2412 / 4665
# Batch 604, count: 2416 / 4665
# Batch 605, count: 2420 / 4665
# Batch 606, count: 2424 / 4665
# Batch 607, count: 2428 / 4665
# Batch 608, count: 2432 / 4665
# Batch 609, count: 2436 / 4665
# Batch 610, count: 2440 / 4665
# Batch 611, count: 2444 / 4665
# Batch 612, count: 2448 / 4665
# Batch 613, count: 2452 / 4665
# Batch 614, count: 2456 / 4665
# Batch 615, count: 2460 / 4665
# Batch 616, count: 2464 / 4665
# Batch 617, count: 2468 / 4665
# Batch 618, count: 2472 / 4665
# Batch 619, count: 2476 / 4665
# Batch 620, count: 2480 / 4665
# Batch 621, count: 2484 / 4665
# Batch 622, count: 2488 / 4665
# Batch 623, count: 2492 / 4665
# Batch 624, count: 2496 / 4665
# Batch 625, count: 2500 / 4665
# Batch 626, count: 2504 / 4665
# Batch 627, count: 2508 / 4665
# Batch 628, count: 2512 / 4665
# Batch 629, count: 2516 / 4665
# Batch 630, count: 2520 / 4665
# Batch 631, count: 2524 / 4665
# Batch 632, count: 2528 / 4665
# Batch 633, count: 2532 / 4665
# Batch 634, count: 2536 / 4665
# Batch 635, count: 2540 / 4665
# Batch 636, count: 2544 / 4665
# Batch 637, count: 2548 / 4665
# Batch 638, count: 2552 / 4665
# Batch 639, count: 2556 / 4665
# Batch 640, count: 2560 / 4665
# Batch 641, count: 2564 / 4665
# Batch 642, count: 2568 / 4665
# Batch 643, count: 2572 / 4665
# Batch 644, count: 2576 / 4665
# Batch 645, count: 2580 / 4665
# Batch 646, count: 2584 / 4665
# Batch 647, count: 2588 / 4665
# Batch 648, count: 2592 / 4665
# Batch 649, count: 2596 / 4665
# Batch 650, count: 2600 / 4665
# Batch 651, count: 2604 / 4665
# Batch 652, count: 2608 / 4665
# Batch 653, count: 2612 / 4665
# Batch 654, count: 2616 / 4665
# Batch 655, count: 2620 / 4665
# Batch 656, count: 2624 / 4665
# Batch 657, count: 2628 / 4665
# Batch 658, count: 2632 / 4665
# Batch 659, count: 2636 / 4665
# Batch 660, count: 2640 / 4665
# Batch 661, count: 2644 / 4665
# Batch 662, count: 2648 / 4665
# Batch 663, count: 2652 / 4665
# Batch 664, count: 2656 / 4665
# Batch 665, count: 2660 / 4665
# Batch 666, count: 2664 / 4665
# Batch 667, count: 2668 / 4665
# Batch 668, count: 2672 / 4665
# Batch 669, count: 2676 / 4665
# Batch 670, count: 2680 / 4665
# Batch 671, count: 2684 / 4665
# Batch 672, count: 2688 / 4665
# Batch 673, count: 2692 / 4665
# Batch 674, count: 2696 / 4665
# Batch 675, count: 2700 / 4665
# Batch 676, count: 2704 / 4665
# Batch 677, count: 2708 / 4665
# Batch 678, count: 2712 / 4665
# Batch 679, count: 2716 / 4665
# Batch 680, count: 2720 / 4665
# Batch 681, count: 2724 / 4665
# Batch 682, count: 2728 / 4665
# Batch 683, count: 2732 / 4665
# Batch 684, count: 2736 / 4665
# Batch 685, count: 2740 / 4665
# Batch 686, count: 2744 / 4665
# Batch 687, count: 2748 / 4665
# Batch 688, count: 2752 / 4665
# Batch 689, count: 2756 / 4665
# Batch 690, count: 2760 / 4665
# Batch 691, count: 2764 / 4665
# Batch 692, count: 2768 / 4665
# Batch 693, count: 2772 / 4665
# Batch 694, count: 2776 / 4665
# Batch 695, count: 2780 / 4665
# Batch 696, count: 2784 / 4665
# Batch 697, count: 2788 / 4665
# Batch 698, count: 2792 / 4665
# Batch 699, count: 2796 / 4665
# Batch 700, count: 2800 / 4665
# Batch 701, count: 2804 / 4665
# Batch 702, count: 2808 / 4665
# Batch 703, count: 2812 / 4665
# Batch 704, count: 2816 / 4665
# Batch 705, count: 2820 / 4665
# Batch 706, count: 2824 / 4665
# Batch 707, count: 2828 / 4665
# Batch 708, count: 2832 / 4665
# Batch 709, count: 2836 / 4665
# Batch 710, count: 2840 / 4665
# Batch 711, count: 2844 / 4665
# Batch 712, count: 2848 / 4665
# Batch 713, count: 2852 / 4665
# Batch 714, count: 2856 / 4665
# Batch 715, count: 2860 / 4665
# Batch 716, count: 2864 / 4665
# Batch 717, count: 2868 / 4665
# Batch 718, count: 2872 / 4665
# Batch 719, count: 2876 / 4665
# Batch 720, count: 2880 / 4665
# Batch 721, count: 2884 / 4665
# Batch 722, count: 2888 / 4665
# Batch 723, count: 2892 / 4665
# Batch 724, count: 2896 / 4665
# Batch 725, count: 2900 / 4665
# Batch 726, count: 2904 / 4665
# Batch 727, count: 2908 / 4665
# Batch 728, count: 2912 / 4665
# Batch 729, count: 2916 / 4665
# Batch 730, count: 2920 / 4665
# Batch 731, count: 2924 / 4665
# Batch 732, count: 2928 / 4665
# Batch 733, count: 2932 / 4665
# Batch 734, count: 2936 / 4665
# Batch 735, count: 2940 / 4665
# Batch 736, count: 2944 / 4665
# Batch 737, count: 2948 / 4665
# Batch 738, count: 2952 / 4665
# Batch 739, count: 2956 / 4665
# Batch 740, count: 2960 / 4665
# Batch 741, count: 2964 / 4665
# Batch 742, count: 2968 / 4665
# Batch 743, count: 2972 / 4665
# Batch 744, count: 2976 / 4665
# Batch 745, count: 2980 / 4665
# Batch 746, count: 2984 / 4665
# Batch 747, count: 2988 / 4665
# Batch 748, count: 2992 / 4665
# Batch 749, count: 2996 / 4665
# Batch 750, count: 3000 / 4665
# Batch 751, count: 3004 / 4665
# Batch 752, count: 3008 / 4665
# Batch 753, count: 3012 / 4665
# Batch 754, count: 3016 / 4665
# Batch 755, count: 3020 / 4665
# Batch 756, count: 3024 / 4665
# Batch 757, count: 3028 / 4665
# Batch 758, count: 3032 / 4665
# Batch 759, count: 3036 / 4665
# Batch 760, count: 3040 / 4665
# Batch 761, count: 3044 / 4665
# Batch 762, count: 3048 / 4665
# Batch 763, count: 3052 / 4665
# Batch 764, count: 3056 / 4665
# Batch 765, count: 3060 / 4665
# Batch 766, count: 3064 / 4665
# Batch 767, count: 3068 / 4665
# Batch 768, count: 3072 / 4665
# Batch 769, count: 3076 / 4665
# Batch 770, count: 3080 / 4665
# Batch 771, count: 3084 / 4665
# Batch 772, count: 3088 / 4665
# Batch 773, count: 3092 / 4665
# Batch 774, count: 3096 / 4665
# Batch 775, count: 3100 / 4665
# Batch 776, count: 3104 / 4665
# Batch 777, count: 3108 / 4665
# Batch 778, count: 3112 / 4665
# Batch 779, count: 3116 / 4665
# Batch 780, count: 3120 / 4665
# Batch 781, count: 3124 / 4665
# Batch 782, count: 3128 / 4665
# Batch 783, count: 3132 / 4665
# Batch 784, count: 3136 / 4665
# Batch 785, count: 3140 / 4665
# Batch 786, count: 3144 / 4665
# Batch 787, count: 3148 / 4665
# Batch 788, count: 3152 / 4665
# Batch 789, count: 3156 / 4665
# Batch 790, count: 3160 / 4665
# Batch 791, count: 3164 / 4665
# Batch 792, count: 3168 / 4665
# Batch 793, count: 3172 / 4665
# Batch 794, count: 3176 / 4665
# Batch 795, count: 3180 / 4665
# Batch 796, count: 3184 / 4665
# Batch 797, count: 3188 / 4665
# Batch 798, count: 3192 / 4665
# Batch 799, count: 3196 / 4665
# Batch 800, count: 3200 / 4665
# Batch 801, count: 3204 / 4665
# Batch 802, count: 3208 / 4665
# Batch 803, count: 3212 / 4665
# Batch 804, count: 3216 / 4665
# Batch 805, count: 3220 / 4665
# Batch 806, count: 3224 / 4665
# Batch 807, count: 3228 / 4665
# Batch 808, count: 3232 / 4665
# Batch 809, count: 3236 / 4665
# Batch 810, count: 3240 / 4665
# Batch 811, count: 3244 / 4665
# Batch 812, count: 3248 / 4665
# Batch 813, count: 3252 / 4665
# Batch 814, count: 3256 / 4665
# Batch 815, count: 3260 / 4665
# Batch 816, count: 3264 / 4665
# Batch 817, count: 3268 / 4665
# Batch 818, count: 3272 / 4665
# Batch 819, count: 3276 / 4665
# Batch 820, count: 3280 / 4665
# Batch 821, count: 3284 / 4665
# Batch 822, count: 3288 / 4665
# Batch 823, count: 3292 / 4665
# Batch 824, count: 3296 / 4665
# Batch 825, count: 3300 / 4665
# Batch 826, count: 3304 / 4665
# Batch 827, count: 3308 / 4665
# Batch 828, count: 3312 / 4665
# Batch 829, count: 3316 / 4665
# Batch 830, count: 3320 / 4665
# Batch 831, count: 3324 / 4665
# Batch 832, count: 3328 / 4665
# Batch 833, count: 3332 / 4665
# Batch 834, count: 3336 / 4665
# Batch 835, count: 3340 / 4665
# Batch 836, count: 3344 / 4665
# Batch 837, count: 3348 / 4665
# Batch 838, count: 3352 / 4665
# Batch 839, count: 3356 / 4665
# Batch 840, count: 3360 / 4665
# Batch 841, count: 3364 / 4665
# Batch 842, count: 3368 / 4665
# Batch 843, count: 3372 / 4665
# Batch 844, count: 3376 / 4665
# Batch 845, count: 3380 / 4665
# Batch 846, count: 3384 / 4665
# Batch 847, count: 3388 / 4665
# Batch 848, count: 3392 / 4665
# Batch 849, count: 3396 / 4665
# Batch 850, count: 3400 / 4665
# Batch 851, count: 3404 / 4665
# Batch 852, count: 3408 / 4665
# Batch 853, count: 3412 / 4665
# Batch 854, count: 3416 / 4665
# Batch 855, count: 3420 / 4665
# Batch 856, count: 3424 / 4665
# Batch 857, count: 3428 / 4665
# Batch 858, count: 3432 / 4665
# Batch 859, count: 3436 / 4665
# Batch 860, count: 3440 / 4665
# Batch 861, count: 3444 / 4665
# Batch 862, count: 3448 / 4665
# Batch 863, count: 3452 / 4665
# Batch 864, count: 3456 / 4665
# Batch 865, count: 3460 / 4665
# Batch 866, count: 3464 / 4665
# Batch 867, count: 3468 / 4665
# Batch 868, count: 3472 / 4665
# Batch 869, count: 3476 / 4665
# Batch 870, count: 3480 / 4665
# Batch 871, count: 3484 / 4665
# Batch 872, count: 3488 / 4665
# Batch 873, count: 3492 / 4665
# Batch 874, count: 3496 / 4665
# Batch 875, count: 3500 / 4665
# Batch 876, count: 3504 / 4665
# Batch 877, count: 3508 / 4665
# Batch 878, count: 3512 / 4665
# Batch 879, count: 3516 / 4665
# Batch 880, count: 3520 / 4665
# Batch 881, count: 3524 / 4665
# Batch 882, count: 3528 / 4665
# Batch 883, count: 3532 / 4665
# Batch 884, count: 3536 / 4665
# Batch 885, count: 3540 / 4665
# Batch 886, count: 3544 / 4665
# Batch 887, count: 3548 / 4665
# Batch 888, count: 3552 / 4665
# Batch 889, count: 3556 / 4665
# Batch 890, count: 3560 / 4665
# Batch 891, count: 3564 / 4665
# Batch 892, count: 3568 / 4665
# Batch 893, count: 3572 / 4665
# Batch 894, count: 3576 / 4665
# Batch 895, count: 3580 / 4665
# Batch 896, count: 3584 / 4665
# Batch 897, count: 3588 / 4665
# Batch 898, count: 3592 / 4665
# Batch 899, count: 3596 / 4665
# Batch 900, count: 3600 / 4665
# Batch 901, count: 3604 / 4665
# Batch 902, count: 3608 / 4665
# Batch 903, count: 3612 / 4665
# Batch 904, count: 3616 / 4665
# Batch 905, count: 3620 / 4665
# Batch 906, count: 3624 / 4665
# Batch 907, count: 3628 / 4665
# Batch 908, count: 3632 / 4665
# Batch 909, count: 3636 / 4665
# Batch 910, count: 3640 / 4665
# Batch 911, count: 3644 / 4665
# Batch 912, count: 3648 / 4665
# Batch 913, count: 3652 / 4665
# Batch 914, count: 3656 / 4665
# Batch 915, count: 3660 / 4665
# Batch 916, count: 3664 / 4665
# Batch 917, count: 3668 / 4665
# Batch 918, count: 3672 / 4665
# Batch 919, count: 3676 / 4665
# Batch 920, count: 3680 / 4665
# Batch 921, count: 3684 / 4665
# Batch 922, count: 3688 / 4665
# Batch 923, count: 3692 / 4665
# Batch 924, count: 3696 / 4665
# Batch 925, count: 3700 / 4665
# Batch 926, count: 3704 / 4665
# Batch 927, count: 3708 / 4665
# Batch 928, count: 3712 / 4665
# Batch 929, count: 3716 / 4665
# Batch 930, count: 3720 / 4665
# Batch 931, count: 3724 / 4665
# Batch 932, count: 3728 / 4665
# Batch 933, count: 3732 / 4665
# Batch 934, count: 3736 / 4665
# Batch 935, count: 3740 / 4665
# Batch 936, count: 3744 / 4665
# Batch 937, count: 3748 / 4665
# Batch 938, count: 3752 / 4665
# Batch 939, count: 3756 / 4665
# Batch 940, count: 3760 / 4665
# Batch 941, count: 3764 / 4665
# Batch 942, count: 3768 / 4665
# Batch 943, count: 3772 / 4665
# Batch 944, count: 3776 / 4665
# Batch 945, count: 3780 / 4665
# Batch 946, count: 3784 / 4665
# Batch 947, count: 3788 / 4665
# Batch 948, count: 3792 / 4665
# Batch 949, count: 3796 / 4665
# Batch 950, count: 3800 / 4665
# Batch 951, count: 3804 / 4665
# Batch 952, count: 3808 / 4665
# Batch 953, count: 3812 / 4665
# Batch 954, count: 3816 / 4665
# Batch 955, count: 3820 / 4665
# Batch 956, count: 3824 / 4665
# Batch 957, count: 3828 / 4665
# Batch 958, count: 3832 / 4665
# Batch 959, count: 3836 / 4665
# Batch 960, count: 3840 / 4665
# Batch 961, count: 3844 / 4665
# Batch 962, count: 3848 / 4665
# Batch 963, count: 3852 / 4665
# Batch 964, count: 3856 / 4665
# Batch 965, count: 3860 / 4665
# Batch 966, count: 3864 / 4665
# Batch 967, count: 3868 / 4665
# Batch 968, count: 3872 / 4665
# Batch 969, count: 3876 / 4665
# Batch 970, count: 3880 / 4665
# Batch 971, count: 3884 / 4665
# Batch 972, count: 3888 / 4665
# Batch 973, count: 3892 / 4665
# Batch 974, count: 3896 / 4665
# Batch 975, count: 3900 / 4665
# Batch 976, count: 3904 / 4665
# Batch 977, count: 3908 / 4665
# Batch 978, count: 3912 / 4665
# Batch 979, count: 3916 / 4665
# Batch 980, count: 3920 / 4665
# Batch 981, count: 3924 / 4665
# Batch 982, count: 3928 / 4665
# Batch 983, count: 3932 / 4665
# Batch 984, count: 3936 / 4665
# Batch 985, count: 3940 / 4665
# Batch 986, count: 3944 / 4665
# Batch 987, count: 3948 / 4665
# Batch 988, count: 3952 / 4665
# Batch 989, count: 3956 / 4665
# Batch 990, count: 3960 / 4665
# Batch 991, count: 3964 / 4665
# Batch 992, count: 3968 / 4665
# Batch 993, count: 3972 / 4665
# Batch 994, count: 3976 / 4665
# Batch 995, count: 3980 / 4665
# Batch 996, count: 3984 / 4665
# Batch 997, count: 3988 / 4665
# Batch 998, count: 3992 / 4665
# Batch 999, count: 3996 / 4665
# Batch 1000, count: 4000 / 4665
# Batch 1001, count: 4004 / 4665
# Batch 1002, count: 4008 / 4665
# Batch 1003, count: 4012 / 4665
# Batch 1004, count: 4016 / 4665
# Batch 1005, count: 4020 / 4665
# Batch 1006, count: 4024 / 4665
# Batch 1007, count: 4028 / 4665
# Batch 1008, count: 4032 / 4665
# Batch 1009, count: 4036 / 4665
# Batch 1010, count: 4040 / 4665
# Batch 1011, count: 4044 / 4665
# Batch 1012, count: 4048 / 4665
# Batch 1013, count: 4052 / 4665
# Batch 1014, count: 4056 / 4665
# Batch 1015, count: 4060 / 4665
# Batch 1016, count: 4064 / 4665
# Batch 1017, count: 4068 / 4665
# Batch 1018, count: 4072 / 4665
# Batch 1019, count: 4076 / 4665
# Batch 1020, count: 4080 / 4665
# Batch 1021, count: 4084 / 4665
# Batch 1022, count: 4088 / 4665
# Batch 1023, count: 4092 / 4665
# Batch 1024, count: 4096 / 4665
# Batch 1025, count: 4100 / 4665
# Batch 1026, count: 4104 / 4665
# Batch 1027, count: 4108 / 4665
# Batch 1028, count: 4112 / 4665
# Batch 1029, count: 4116 / 4665
# Batch 1030, count: 4120 / 4665
# Batch 1031, count: 4124 / 4665
# Batch 1032, count: 4128 / 4665
# Batch 1033, count: 4132 / 4665
# Batch 1034, count: 4136 / 4665
# Batch 1035, count: 4140 / 4665
# Batch 1036, count: 4144 / 4665
# Batch 1037, count: 4148 / 4665
# Batch 1038, count: 4152 / 4665
# Batch 1039, count: 4156 / 4665
# Batch 1040, count: 4160 / 4665
# Batch 1041, count: 4164 / 4665
# Batch 1042, count: 4168 / 4665
# Batch 1043, count: 4172 / 4665
# Batch 1044, count: 4176 / 4665
# Batch 1045, count: 4180 / 4665
# Batch 1046, count: 4184 / 4665
# Batch 1047, count: 4188 / 4665
# Batch 1048, count: 4192 / 4665
# Batch 1049, count: 4196 / 4665
# Batch 1050, count: 4200 / 4665
# Batch 1051, count: 4204 / 4665
# Batch 1052, count: 4208 / 4665
# Batch 1053, count: 4212 / 4665
# Batch 1054, count: 4216 / 4665
# Batch 1055, count: 4220 / 4665
# Batch 1056, count: 4224 / 4665
# Batch 1057, count: 4228 / 4665
# Batch 1058, count: 4232 / 4665
# Batch 1059, count: 4236 / 4665
# Batch 1060, count: 4240 / 4665
# Batch 1061, count: 4244 / 4665
# Batch 1062, count: 4248 / 4665
# Batch 1063, count: 4252 / 4665
# Batch 1064, count: 4256 / 4665
# Batch 1065, count: 4260 / 4665
# Batch 1066, count: 4264 / 4665
# Batch 1067, count: 4268 / 4665
# Batch 1068, count: 4272 / 4665
# Batch 1069, count: 4276 / 4665
# Batch 1070, count: 4280 / 4665
# Batch 1071, count: 4284 / 4665
# Batch 1072, count: 4288 / 4665
# Batch 1073, count: 4292 / 4665
# Batch 1074, count: 4296 / 4665
# Batch 1075, count: 4300 / 4665
# Batch 1076, count: 4304 / 4665
# Batch 1077, count: 4308 / 4665
# Batch 1078, count: 4312 / 4665
# Batch 1079, count: 4316 / 4665
# Batch 1080, count: 4320 / 4665
# Batch 1081, count: 4324 / 4665
# Batch 1082, count: 4328 / 4665
# Batch 1083, count: 4332 / 4665
# Batch 1084, count: 4336 / 4665
# Batch 1085, count: 4340 / 4665
# Batch 1086, count: 4344 / 4665
# Batch 1087, count: 4348 / 4665
# Batch 1088, count: 4352 / 4665
# Batch 1089, count: 4356 / 4665
# Batch 1090, count: 4360 / 4665
# Batch 1091, count: 4364 / 4665
# Batch 1092, count: 4368 / 4665
# Batch 1093, count: 4372 / 4665
# Batch 1094, count: 4376 / 4665
# Batch 1095, count: 4380 / 4665
# Batch 1096, count: 4384 / 4665
# Batch 1097, count: 4388 / 4665
# Batch 1098, count: 4392 / 4665
# Batch 1099, count: 4396 / 4665
# Batch 1100, count: 4400 / 4665
# Batch 1101, count: 4404 / 4665
# Batch 1102, count: 4408 / 4665
# Batch 1103, count: 4412 / 4665
# Batch 1104, count: 4416 / 4665
# Batch 1105, count: 4420 / 4665
# Batch 1106, count: 4424 / 4665
# Batch 1107, count: 4428 / 4665
# Batch 1108, count: 4432 / 4665
# Batch 1109, count: 4436 / 4665
# Batch 1110, count: 4440 / 4665
# Batch 1111, count: 4444 / 4665
# Batch 1112, count: 4448 / 4665
# Batch 1113, count: 4452 / 4665
# Batch 1114, count: 4456 / 4665
# Batch 1115, count: 4460 / 4665
# Batch 1116, count: 4464 / 4665
# Batch 1117, count: 4468 / 4665
# Batch 1118, count: 4472 / 4665
# Batch 1119, count: 4476 / 4665
# Batch 1120, count: 4480 / 4665
# Batch 1121, count: 4484 / 4665
# Batch 1122, count: 4488 / 4665
# Batch 1123, count: 4492 / 4665
# Batch 1124, count: 4496 / 4665
# Batch 1125, count: 4500 / 4665
# Batch 1126, count: 4504 / 4665
# Batch 1127, count: 4508 / 4665
# Batch 1128, count: 4512 / 4665
# Batch 1129, count: 4516 / 4665
# Batch 1130, count: 4520 / 4665
# Batch 1131, count: 4524 / 4665
# Batch 1132, count: 4528 / 4665
# Batch 1133, count: 4532 / 4665
# Batch 1134, count: 4536 / 4665
# Batch 1135, count: 4540 / 4665
# Batch 1136, count: 4544 / 4665
# Batch 1137, count: 4548 / 4665
# Batch 1138, count: 4552 / 4665
# Batch 1139, count: 4556 / 4665
# Batch 1140, count: 4560 / 4665
# Batch 1141, count: 4564 / 4665
# Batch 1142, count: 4568 / 4665
# Batch 1143, count: 4572 / 4665
# Batch 1144, count: 4576 / 4665
# Batch 1145, count: 4580 / 4665
# Batch 1146, count: 4584 / 4665
# Batch 1147, count: 4588 / 4665
# Batch 1148, count: 4592 / 4665
# Batch 1149, count: 4596 / 4665
# Batch 1150, count: 4600 / 4665
# Batch 1151, count: 4604 / 4665
# Batch 1152, count: 4608 / 4665
# Batch 1153, count: 4612 / 4665
# Batch 1154, count: 4616 / 4665
# Batch 1155, count: 4620 / 4665
# Batch 1156, count: 4624 / 4665
# Batch 1157, count: 4628 / 4665
# Batch 1158, count: 4632 / 4665
# Batch 1159, count: 4636 / 4665
# Batch 1160, count: 4640 / 4665
# Batch 1161, count: 4644 / 4665
# Batch 1162, count: 4648 / 4665
# Batch 1163, count: 4652 / 4665
# Batch 1164, count: 4656 / 4665
# Batch 1165, count: 4660 / 4665
# Batch 1166, count: 4664 / 4665
