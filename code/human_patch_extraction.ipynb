# %%
import random
import time
import os

import cv2
import numpy as np

import torch
import torchvision
from PIL import Image
from IPython import display

import torchvision.models
from torchvision.transforms import transforms

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
if (torch.cuda.device_count()>0):
    print(torch.cuda.get_device_name(0))
# Out:
# cuda:0
# NVIDIA GeForce GTX 1080

# %%
model = torchvision.models.detection.maskrcnn_resnet50_fpn_v2(weights="DEFAULT")
model.to(device).eval()
;
# Out:
# ''

# %%
img_directory = "./frames/Train/Game"
output_directory = "./output/segmented/Train/Game"
batch_size = 4

# %%
file_names = [file_name for file_name in os.listdir(img_directory) if file_name.endswith(".jpg")]
len(file_names)
# Out:
# 5078

# %%
file_names[:10]
# Out:
# ['Train_Game_01_00001.jpg',
#  'Train_Game_01_00002.jpg',
#  'Train_Game_01_00003.jpg',
#  'Train_Game_01_00004.jpg',
#  'Train_Game_01_00005.jpg',
#  'Train_Game_01_00006.jpg',
#  'Train_Game_01_00007.jpg',
#  'Train_Game_01_00008.jpg',
#  'Train_Game_01_00009.jpg',
#  'Train_Game_01_00010.jpg']

# %%
transform = transforms.Compose([
    transforms.ToTensor()
])

def batch_loader(directory, file_names, batch_size):
    for i in range(len(file_names) // batch_size + 1):
        selected = []
        start_idx = batch_size * i
        limit_idx = batch_size * (i + 1)
        
        if limit_idx > len(file_names):
            selected = file_names[start_idx:]
        else:
            selected = file_names[start_idx:limit_idx]
            
        if len(selected) == 0:
            break
        
        output_files = []
        raw_frames = []
        usable_frames = []
        
        for file_name in selected:
            output_files.append(f"{output_directory}/Segmented_{file_name.split('.')[0]}")
            input_file = f"{directory}/{file_name}"
            raw_frame = cv2.imread(input_file, cv2.IMREAD_COLOR)
            raw_frames.append(raw_frame)
            
            usable_frame = cv2.cvtColor(raw_frame, cv2.COLOR_BGR2RGB)
            usable_frame = transform(usable_frame)
            usable_frames.append(usable_frame)
        
        stacked_frames = torch.stack(usable_frames).to(device)
        yield stacked_frames, raw_frames, output_files
            
batch_generator = batch_loader(img_directory, file_names, batch_size)

# %%
# The 91 COCO class names
coco_names = ['__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table', 'N/A', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# Generate a set of color for drawing different classes
COLORS = np.random.uniform(0, 255, size=(len(coco_names), 3))

threshold = 0.965

# %%
def process_maskrcnn_output(output, frame, save_loc, threshold):
    scores = list(output['scores'].detach().cpu().numpy()) # Get scores
    thresholded_objects = [scores.index(i) for i in scores if i > threshold]
    thresholded_objects_count = len(thresholded_objects)
    masks = (output['masks']>0.5).squeeze().detach().cpu().numpy()
    masks = masks[:thresholded_objects_count]
    boxes = [[(i[0], i[1]), (i[2], i[3])]  for i in output['boxes'].detach().cpu()]
    boxes = boxes[:thresholded_objects_count]
    labels = [coco_names[i] for i in output['labels']][:thresholded_objects_count]
    
    for i, label in enumerate(labels):
        if label != "person":
            continue
            
        
        out_frame = np.array(frame.copy())
        out_frame = out_frame[int(boxes[i][0][1]):int(boxes[i][1][1]), int(boxes[i][0][0]):int(boxes[i][1][0])]
        
        cv2.imwrite(f"{save_loc}_{i}.jpg", out_frame)
        
    
    return
    
    print(scores) # The scores are sorted from largest to the shortest
    thresholded_objects = [scores.index(i) for i in scores if i > threshold] # Get an index for the objects having the scores > a threshold of 0.965
    thresholded_objects_count = len(thresholded_objects) # Total objects having scores > threshold
    masks = (output['masks']>0.5).squeeze().detach().cpu().numpy() # Get the segmentation masks
    masks = masks[:thresholded_objects_count] # Discard masks for objects that are below threshold by only taking the beginning of the list
    boxes = [[(i[0], i[1]), (i[2], i[3])]  for i in output['boxes'].detach().cpu()] # Get the bounding boxes, in (x1, y1), (x2, y2) format
    boxes = boxes[:thresholded_objects_count] # Discard bounding boxes for objects that are below threshold by only taking the beginning of the list
    labels = [coco_names[i] for i in output['labels']] # Get the classes labels
    
    out_frame = np.array(frame.copy())
    
    # Draw the segmentation masks with the text labels
    for i in range(len(masks)): # For all detected objects with score > threshold
        color = COLORS[random.randrange(0, len(COLORS))] # Pick a random color
        red_map = np.zeros_like(masks[i]).astype(np.uint8) # Initialize an empty mask for each of the RGB channels
        green_map = np.zeros_like(masks[i]).astype(np.uint8)
        blue_map = np.zeros_like(masks[i]).astype(np.uint8)
        red_map[masks[i] == 1], green_map[masks[i] == 1], blue_map[masks[i] == 1] = color # Set the color of the masked pixels
        segmentation_map = np.stack([red_map, green_map, blue_map], axis=2) # Combine the three channels of the mask
        cv2.addWeighted(out_frame, 1.0, segmentation_map, 0.6, 0.0, out_frame) # Apply the mask onto the image
        cv2.rectangle(out_frame, (int(boxes[i][0][0]),int(boxes[i][0][1])), (int(boxes[i][1][0]),int(boxes[i][1][1])), color, 2) # Draw the bounding boxes
        cv2.putText(out_frame , labels[i], (int(boxes[i][0][0]), int(boxes[i][0][1])-10), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2, cv2.LINE_AA) # Draw the class label as text
    
    cv2.imwrite(save_loc, out_frame)

# %%
batch_generator = batch_loader(img_directory, file_names, batch_size)

for i, (batch, raw_frames, output_files) in enumerate(batch_generator):
    print(f"Batch {i}, count: {i * batch_size} / {len(file_names)}")
    with torch.no_grad():
        outputs = model(batch)
    
    for output, frame, output_file in zip(outputs, raw_frames, output_files):
        process_maskrcnn_output(output, frame, output_file, threshold)
# Out:
# Batch 0, count: 0 / 5078
# Batch 1, count: 4 / 5078
# Batch 2, count: 8 / 5078
# Batch 3, count: 12 / 5078
# Batch 4, count: 16 / 5078
# Batch 5, count: 20 / 5078
# Batch 6, count: 24 / 5078
# Batch 7, count: 28 / 5078
# Batch 8, count: 32 / 5078
# Batch 9, count: 36 / 5078
# Batch 10, count: 40 / 5078
# Batch 11, count: 44 / 5078
# Batch 12, count: 48 / 5078
# Batch 13, count: 52 / 5078
# Batch 14, count: 56 / 5078
# Batch 15, count: 60 / 5078
# Batch 16, count: 64 / 5078
# Batch 17, count: 68 / 5078
# Batch 18, count: 72 / 5078
# Batch 19, count: 76 / 5078
# Batch 20, count: 80 / 5078
# Batch 21, count: 84 / 5078
# Batch 22, count: 88 / 5078
# Batch 23, count: 92 / 5078
# Batch 24, count: 96 / 5078
# Batch 25, count: 100 / 5078
# Batch 26, count: 104 / 5078
# Batch 27, count: 108 / 5078
# Batch 28, count: 112 / 5078
# Batch 29, count: 116 / 5078
# Batch 30, count: 120 / 5078
# Batch 31, count: 124 / 5078
# Batch 32, count: 128 / 5078
# Batch 33, count: 132 / 5078
# Batch 34, count: 136 / 5078
# Batch 35, count: 140 / 5078
# Batch 36, count: 144 / 5078
# Batch 37, count: 148 / 5078
# Batch 38, count: 152 / 5078
# Batch 39, count: 156 / 5078
# Batch 40, count: 160 / 5078
# Batch 41, count: 164 / 5078
# Batch 42, count: 168 / 5078
# Batch 43, count: 172 / 5078
# Batch 44, count: 176 / 5078
# Batch 45, count: 180 / 5078
# Batch 46, count: 184 / 5078
# Batch 47, count: 188 / 5078
# Batch 48, count: 192 / 5078
# Batch 49, count: 196 / 5078
# Batch 50, count: 200 / 5078
# Batch 51, count: 204 / 5078
# Batch 52, count: 208 / 5078
# Batch 53, count: 212 / 5078
# Batch 54, count: 216 / 5078
# Batch 55, count: 220 / 5078
# Batch 56, count: 224 / 5078
# Batch 57, count: 228 / 5078
# Batch 58, count: 232 / 5078
# Batch 59, count: 236 / 5078
# Batch 60, count: 240 / 5078
# Batch 61, count: 244 / 5078
# Batch 62, count: 248 / 5078
# Batch 63, count: 252 / 5078
# Batch 64, count: 256 / 5078
# Batch 65, count: 260 / 5078
# Batch 66, count: 264 / 5078
# Batch 67, count: 268 / 5078
# Batch 68, count: 272 / 5078
# Batch 69, count: 276 / 5078
# Batch 70, count: 280 / 5078
# Batch 71, count: 284 / 5078
# Batch 72, count: 288 / 5078
# Batch 73, count: 292 / 5078
# Batch 74, count: 296 / 5078
# Batch 75, count: 300 / 5078
# Batch 76, count: 304 / 5078
# Batch 77, count: 308 / 5078
# Batch 78, count: 312 / 5078
# Batch 79, count: 316 / 5078
# Batch 80, count: 320 / 5078
# Batch 81, count: 324 / 5078
# Batch 82, count: 328 / 5078
# Batch 83, count: 332 / 5078
# Batch 84, count: 336 / 5078
# Batch 85, count: 340 / 5078
# Batch 86, count: 344 / 5078
# Batch 87, count: 348 / 5078
# Batch 88, count: 352 / 5078
# Batch 89, count: 356 / 5078
# Batch 90, count: 360 / 5078
# Batch 91, count: 364 / 5078
# Batch 92, count: 368 / 5078
# Batch 93, count: 372 / 5078
# Batch 94, count: 376 / 5078
# Batch 95, count: 380 / 5078
# Batch 96, count: 384 / 5078
# Batch 97, count: 388 / 5078
# Batch 98, count: 392 / 5078
# Batch 99, count: 396 / 5078
# Batch 100, count: 400 / 5078
# Batch 101, count: 404 / 5078
# Batch 102, count: 408 / 5078
# Batch 103, count: 412 / 5078
# Batch 104, count: 416 / 5078
# Batch 105, count: 420 / 5078
# Batch 106, count: 424 / 5078
# Batch 107, count: 428 / 5078
# Batch 108, count: 432 / 5078
# Batch 109, count: 436 / 5078
# Batch 110, count: 440 / 5078
# Batch 111, count: 444 / 5078
# Batch 112, count: 448 / 5078
# Batch 113, count: 452 / 5078
# Batch 114, count: 456 / 5078
# Batch 115, count: 460 / 5078
# Batch 116, count: 464 / 5078
# Batch 117, count: 468 / 5078
# Batch 118, count: 472 / 5078
# Batch 119, count: 476 / 5078
# Batch 120, count: 480 / 5078
# Batch 121, count: 484 / 5078
# Batch 122, count: 488 / 5078
# Batch 123, count: 492 / 5078
# Batch 124, count: 496 / 5078
# Batch 125, count: 500 / 5078
# Batch 126, count: 504 / 5078
# Batch 127, count: 508 / 5078
# Batch 128, count: 512 / 5078
# Batch 129, count: 516 / 5078
# Batch 130, count: 520 / 5078
# Batch 131, count: 524 / 5078
# Batch 132, count: 528 / 5078
# Batch 133, count: 532 / 5078
# Batch 134, count: 536 / 5078
# Batch 135, count: 540 / 5078
# Batch 136, count: 544 / 5078
# Batch 137, count: 548 / 5078
# Batch 138, count: 552 / 5078
# Batch 139, count: 556 / 5078
# Batch 140, count: 560 / 5078
# Batch 141, count: 564 / 5078
# Batch 142, count: 568 / 5078
# Batch 143, count: 572 / 5078
# Batch 144, count: 576 / 5078
# Batch 145, count: 580 / 5078
# Batch 146, count: 584 / 5078
# Batch 147, count: 588 / 5078
# Batch 148, count: 592 / 5078
# Batch 149, count: 596 / 5078
# Batch 150, count: 600 / 5078
# Batch 151, count: 604 / 5078
# Batch 152, count: 608 / 5078
# Batch 153, count: 612 / 5078
# Batch 154, count: 616 / 5078
# Batch 155, count: 620 / 5078
# Batch 156, count: 624 / 5078
# Batch 157, count: 628 / 5078
# Batch 158, count: 632 / 5078
# Batch 159, count: 636 / 5078
# Batch 160, count: 640 / 5078
# Batch 161, count: 644 / 5078
# Batch 162, count: 648 / 5078
# Batch 163, count: 652 / 5078
# Batch 164, count: 656 / 5078
# Batch 165, count: 660 / 5078
# Batch 166, count: 664 / 5078
# Batch 167, count: 668 / 5078
# Batch 168, count: 672 / 5078
# Batch 169, count: 676 / 5078
# Batch 170, count: 680 / 5078
# Batch 171, count: 684 / 5078
# Batch 172, count: 688 / 5078
# Batch 173, count: 692 / 5078
# Batch 174, count: 696 / 5078
# Batch 175, count: 700 / 5078
# Batch 176, count: 704 / 5078
# Batch 177, count: 708 / 5078
# Batch 178, count: 712 / 5078
# Batch 179, count: 716 / 5078
# Batch 180, count: 720 / 5078
# Batch 181, count: 724 / 5078
# Batch 182, count: 728 / 5078
# Batch 183, count: 732 / 5078
# Batch 184, count: 736 / 5078
# Batch 185, count: 740 / 5078
# Batch 186, count: 744 / 5078
# Batch 187, count: 748 / 5078
# Batch 188, count: 752 / 5078
# Batch 189, count: 756 / 5078
# Batch 190, count: 760 / 5078
# Batch 191, count: 764 / 5078
# Batch 192, count: 768 / 5078
# Batch 193, count: 772 / 5078
# Batch 194, count: 776 / 5078
# Batch 195, count: 780 / 5078
# Batch 196, count: 784 / 5078
# Batch 197, count: 788 / 5078
# Batch 198, count: 792 / 5078
# Batch 199, count: 796 / 5078
# Batch 200, count: 800 / 5078
# Batch 201, count: 804 / 5078
# Batch 202, count: 808 / 5078
# Batch 203, count: 812 / 5078
# Batch 204, count: 816 / 5078
# Batch 205, count: 820 / 5078
# Batch 206, count: 824 / 5078
# Batch 207, count: 828 / 5078
# Batch 208, count: 832 / 5078
# Batch 209, count: 836 / 5078
# Batch 210, count: 840 / 5078
# Batch 211, count: 844 / 5078
# Batch 212, count: 848 / 5078
# Batch 213, count: 852 / 5078
# Batch 214, count: 856 / 5078
# Batch 215, count: 860 / 5078
# Batch 216, count: 864 / 5078
# Batch 217, count: 868 / 5078
# Batch 218, count: 872 / 5078
# Batch 219, count: 876 / 5078
# Batch 220, count: 880 / 5078
# Batch 221, count: 884 / 5078
# Batch 222, count: 888 / 5078
# Batch 223, count: 892 / 5078
# Batch 224, count: 896 / 5078
# Batch 225, count: 900 / 5078
# Batch 226, count: 904 / 5078
# Batch 227, count: 908 / 5078
# Batch 228, count: 912 / 5078
# Batch 229, count: 916 / 5078
# Batch 230, count: 920 / 5078
# Batch 231, count: 924 / 5078
# Batch 232, count: 928 / 5078
# Batch 233, count: 932 / 5078
# Batch 234, count: 936 / 5078
# Batch 235, count: 940 / 5078
# Batch 236, count: 944 / 5078
# Batch 237, count: 948 / 5078
# Batch 238, count: 952 / 5078
# Batch 239, count: 956 / 5078
# Batch 240, count: 960 / 5078
# Batch 241, count: 964 / 5078
# Batch 242, count: 968 / 5078
# Batch 243, count: 972 / 5078
# Batch 244, count: 976 / 5078
# Batch 245, count: 980 / 5078
# Batch 246, count: 984 / 5078
# Batch 247, count: 988 / 5078
# Batch 248, count: 992 / 5078
# Batch 249, count: 996 / 5078
# Batch 250, count: 1000 / 5078
# Batch 251, count: 1004 / 5078
# Batch 252, count: 1008 / 5078
# Batch 253, count: 1012 / 5078
# Batch 254, count: 1016 / 5078
# Batch 255, count: 1020 / 5078
# Batch 256, count: 1024 / 5078
# Batch 257, count: 1028 / 5078
# Batch 258, count: 1032 / 5078
# Batch 259, count: 1036 / 5078
# Batch 260, count: 1040 / 5078
# Batch 261, count: 1044 / 5078
# Batch 262, count: 1048 / 5078
# Batch 263, count: 1052 / 5078
# Batch 264, count: 1056 / 5078
# Batch 265, count: 1060 / 5078
# Batch 266, count: 1064 / 5078
# Batch 267, count: 1068 / 5078
# Batch 268, count: 1072 / 5078
# Batch 269, count: 1076 / 5078
# Batch 270, count: 1080 / 5078
# Batch 271, count: 1084 / 5078
# Batch 272, count: 1088 / 5078
# Batch 273, count: 1092 / 5078
# Batch 274, count: 1096 / 5078
# Batch 275, count: 1100 / 5078
# Batch 276, count: 1104 / 5078
# Batch 277, count: 1108 / 5078
# Batch 278, count: 1112 / 5078
# Batch 279, count: 1116 / 5078
# Batch 280, count: 1120 / 5078
# Batch 281, count: 1124 / 5078
# Batch 282, count: 1128 / 5078
# Batch 283, count: 1132 / 5078
# Batch 284, count: 1136 / 5078
# Batch 285, count: 1140 / 5078
# Batch 286, count: 1144 / 5078
# Batch 287, count: 1148 / 5078
# Batch 288, count: 1152 / 5078
# Batch 289, count: 1156 / 5078
# Batch 290, count: 1160 / 5078
# Batch 291, count: 1164 / 5078
# Batch 292, count: 1168 / 5078
# Batch 293, count: 1172 / 5078
# Batch 294, count: 1176 / 5078
# Batch 295, count: 1180 / 5078
# Batch 296, count: 1184 / 5078
# Batch 297, count: 1188 / 5078
# Batch 298, count: 1192 / 5078
# Batch 299, count: 1196 / 5078
# Batch 300, count: 1200 / 5078
# Batch 301, count: 1204 / 5078
# Batch 302, count: 1208 / 5078
# Batch 303, count: 1212 / 5078
# Batch 304, count: 1216 / 5078
# Batch 305, count: 1220 / 5078
# Batch 306, count: 1224 / 5078
# Batch 307, count: 1228 / 5078
# Batch 308, count: 1232 / 5078
# Batch 309, count: 1236 / 5078
# Batch 310, count: 1240 / 5078
# Batch 311, count: 1244 / 5078
# Batch 312, count: 1248 / 5078
# Batch 313, count: 1252 / 5078
# Batch 314, count: 1256 / 5078
# Batch 315, count: 1260 / 5078
# Batch 316, count: 1264 / 5078
# Batch 317, count: 1268 / 5078
# Batch 318, count: 1272 / 5078
# Batch 319, count: 1276 / 5078
# Batch 320, count: 1280 / 5078
# Batch 321, count: 1284 / 5078
# Batch 322, count: 1288 / 5078
# Batch 323, count: 1292 / 5078
# Batch 324, count: 1296 / 5078
# Batch 325, count: 1300 / 5078
# Batch 326, count: 1304 / 5078
# Batch 327, count: 1308 / 5078
# Batch 328, count: 1312 / 5078
# Batch 329, count: 1316 / 5078
# Batch 330, count: 1320 / 5078
# Batch 331, count: 1324 / 5078
# Batch 332, count: 1328 / 5078
# Batch 333, count: 1332 / 5078
# Batch 334, count: 1336 / 5078
# Batch 335, count: 1340 / 5078
# Batch 336, count: 1344 / 5078
# Batch 337, count: 1348 / 5078
# Batch 338, count: 1352 / 5078
# Batch 339, count: 1356 / 5078
# Batch 340, count: 1360 / 5078
# Batch 341, count: 1364 / 5078
# Batch 342, count: 1368 / 5078
# Batch 343, count: 1372 / 5078
# Batch 344, count: 1376 / 5078
# Batch 345, count: 1380 / 5078
# Batch 346, count: 1384 / 5078
# Batch 347, count: 1388 / 5078
# Batch 348, count: 1392 / 5078
# Batch 349, count: 1396 / 5078
# Batch 350, count: 1400 / 5078
# Batch 351, count: 1404 / 5078
# Batch 352, count: 1408 / 5078
# Batch 353, count: 1412 / 5078
# Batch 354, count: 1416 / 5078
# Batch 355, count: 1420 / 5078
# Batch 356, count: 1424 / 5078
# Batch 357, count: 1428 / 5078
# Batch 358, count: 1432 / 5078
# Batch 359, count: 1436 / 5078
# Batch 360, count: 1440 / 5078
# Batch 361, count: 1444 / 5078
# Batch 362, count: 1448 / 5078
# Batch 363, count: 1452 / 5078
# Batch 364, count: 1456 / 5078
# Batch 365, count: 1460 / 5078
# Batch 366, count: 1464 / 5078
# Batch 367, count: 1468 / 5078
# Batch 368, count: 1472 / 5078
# Batch 369, count: 1476 / 5078
# Batch 370, count: 1480 / 5078
# Batch 371, count: 1484 / 5078
# Batch 372, count: 1488 / 5078
# Batch 373, count: 1492 / 5078
# Batch 374, count: 1496 / 5078
# Batch 375, count: 1500 / 5078
# Batch 376, count: 1504 / 5078
# Batch 377, count: 1508 / 5078
# Batch 378, count: 1512 / 5078
# Batch 379, count: 1516 / 5078
# Batch 380, count: 1520 / 5078
# Batch 381, count: 1524 / 5078
# Batch 382, count: 1528 / 5078
# Batch 383, count: 1532 / 5078
# Batch 384, count: 1536 / 5078
# Batch 385, count: 1540 / 5078
# Batch 386, count: 1544 / 5078
# Batch 387, count: 1548 / 5078
# Batch 388, count: 1552 / 5078
# Batch 389, count: 1556 / 5078
# Batch 390, count: 1560 / 5078
# Batch 391, count: 1564 / 5078
# Batch 392, count: 1568 / 5078
# Batch 393, count: 1572 / 5078
# Batch 394, count: 1576 / 5078
# Batch 395, count: 1580 / 5078
# Batch 396, count: 1584 / 5078
# Batch 397, count: 1588 / 5078
# Batch 398, count: 1592 / 5078
# Batch 399, count: 1596 / 5078
# Batch 400, count: 1600 / 5078
# Batch 401, count: 1604 / 5078
# Batch 402, count: 1608 / 5078
# Batch 403, count: 1612 / 5078
# Batch 404, count: 1616 / 5078
# Batch 405, count: 1620 / 5078
# Batch 406, count: 1624 / 5078
# Batch 407, count: 1628 / 5078
# Batch 408, count: 1632 / 5078
# Batch 409, count: 1636 / 5078
# Batch 410, count: 1640 / 5078
# Batch 411, count: 1644 / 5078
# Batch 412, count: 1648 / 5078
# Batch 413, count: 1652 / 5078
# Batch 414, count: 1656 / 5078
# Batch 415, count: 1660 / 5078
# Batch 416, count: 1664 / 5078
# Batch 417, count: 1668 / 5078
# Batch 418, count: 1672 / 5078
# Batch 419, count: 1676 / 5078
# Batch 420, count: 1680 / 5078
# Batch 421, count: 1684 / 5078
# Batch 422, count: 1688 / 5078
# Batch 423, count: 1692 / 5078
# Batch 424, count: 1696 / 5078
# Batch 425, count: 1700 / 5078
# Batch 426, count: 1704 / 5078
# Batch 427, count: 1708 / 5078
# Batch 428, count: 1712 / 5078
# Batch 429, count: 1716 / 5078
# Batch 430, count: 1720 / 5078
# Batch 431, count: 1724 / 5078
# Batch 432, count: 1728 / 5078
# Batch 433, count: 1732 / 5078
# Batch 434, count: 1736 / 5078
# Batch 435, count: 1740 / 5078
# Batch 436, count: 1744 / 5078
# Batch 437, count: 1748 / 5078
# Batch 438, count: 1752 / 5078
# Batch 439, count: 1756 / 5078
# Batch 440, count: 1760 / 5078
# Batch 441, count: 1764 / 5078
# Batch 442, count: 1768 / 5078
# Batch 443, count: 1772 / 5078
# Batch 444, count: 1776 / 5078
# Batch 445, count: 1780 / 5078
# Batch 446, count: 1784 / 5078
# Batch 447, count: 1788 / 5078
# Batch 448, count: 1792 / 5078
# Batch 449, count: 1796 / 5078
# Batch 450, count: 1800 / 5078
# Batch 451, count: 1804 / 5078
# Batch 452, count: 1808 / 5078
# Batch 453, count: 1812 / 5078
# Batch 454, count: 1816 / 5078
# Batch 455, count: 1820 / 5078
# Batch 456, count: 1824 / 5078
# Batch 457, count: 1828 / 5078
# Batch 458, count: 1832 / 5078
# Batch 459, count: 1836 / 5078
# Batch 460, count: 1840 / 5078
# Batch 461, count: 1844 / 5078
# Batch 462, count: 1848 / 5078
# Batch 463, count: 1852 / 5078
# Batch 464, count: 1856 / 5078
# Batch 465, count: 1860 / 5078
# Batch 466, count: 1864 / 5078
# Batch 467, count: 1868 / 5078
# Batch 468, count: 1872 / 5078
# Batch 469, count: 1876 / 5078
# Batch 470, count: 1880 / 5078
# Batch 471, count: 1884 / 5078
# Batch 472, count: 1888 / 5078
# Batch 473, count: 1892 / 5078
# Batch 474, count: 1896 / 5078
# Batch 475, count: 1900 / 5078
# Batch 476, count: 1904 / 5078
# Batch 477, count: 1908 / 5078
# Batch 478, count: 1912 / 5078
# Batch 479, count: 1916 / 5078
# Batch 480, count: 1920 / 5078
# Batch 481, count: 1924 / 5078
# Batch 482, count: 1928 / 5078
# Batch 483, count: 1932 / 5078
# Batch 484, count: 1936 / 5078
# Batch 485, count: 1940 / 5078
# Batch 486, count: 1944 / 5078
# Batch 487, count: 1948 / 5078
# Batch 488, count: 1952 / 5078
# Batch 489, count: 1956 / 5078
# Batch 490, count: 1960 / 5078
# Batch 491, count: 1964 / 5078
# Batch 492, count: 1968 / 5078
# Batch 493, count: 1972 / 5078
# Batch 494, count: 1976 / 5078
# Batch 495, count: 1980 / 5078
# Batch 496, count: 1984 / 5078
# Batch 497, count: 1988 / 5078
# Batch 498, count: 1992 / 5078
# Batch 499, count: 1996 / 5078
# Batch 500, count: 2000 / 5078
# Batch 501, count: 2004 / 5078
# Batch 502, count: 2008 / 5078
# Batch 503, count: 2012 / 5078
# Batch 504, count: 2016 / 5078
# Batch 505, count: 2020 / 5078
# Batch 506, count: 2024 / 5078
# Batch 507, count: 2028 / 5078
# Batch 508, count: 2032 / 5078
# Batch 509, count: 2036 / 5078
# Batch 510, count: 2040 / 5078
# Batch 511, count: 2044 / 5078
# Batch 512, count: 2048 / 5078
# Batch 513, count: 2052 / 5078
# Batch 514, count: 2056 / 5078
# Batch 515, count: 2060 / 5078
# Batch 516, count: 2064 / 5078
# Batch 517, count: 2068 / 5078
# Batch 518, count: 2072 / 5078
# Batch 519, count: 2076 / 5078
# Batch 520, count: 2080 / 5078
# Batch 521, count: 2084 / 5078
# Batch 522, count: 2088 / 5078
# Batch 523, count: 2092 / 5078
# Batch 524, count: 2096 / 5078
# Batch 525, count: 2100 / 5078
# Batch 526, count: 2104 / 5078
# Batch 527, count: 2108 / 5078
# Batch 528, count: 2112 / 5078
# Batch 529, count: 2116 / 5078
# Batch 530, count: 2120 / 5078
# Batch 531, count: 2124 / 5078
# Batch 532, count: 2128 / 5078
# Batch 533, count: 2132 / 5078
# Batch 534, count: 2136 / 5078
# Batch 535, count: 2140 / 5078
# Batch 536, count: 2144 / 5078
# Batch 537, count: 2148 / 5078
# Batch 538, count: 2152 / 5078
# Batch 539, count: 2156 / 5078
# Batch 540, count: 2160 / 5078
# Batch 541, count: 2164 / 5078
# Batch 542, count: 2168 / 5078
# Batch 543, count: 2172 / 5078
# Batch 544, count: 2176 / 5078
# Batch 545, count: 2180 / 5078
# Batch 546, count: 2184 / 5078
# Batch 547, count: 2188 / 5078
# Batch 548, count: 2192 / 5078
# Batch 549, count: 2196 / 5078
# Batch 550, count: 2200 / 5078
# Batch 551, count: 2204 / 5078
# Batch 552, count: 2208 / 5078
# Batch 553, count: 2212 / 5078
# Batch 554, count: 2216 / 5078
# Batch 555, count: 2220 / 5078
# Batch 556, count: 2224 / 5078
# Batch 557, count: 2228 / 5078
# Batch 558, count: 2232 / 5078
# Batch 559, count: 2236 / 5078
# Batch 560, count: 2240 / 5078
# Batch 561, count: 2244 / 5078
# Batch 562, count: 2248 / 5078
# Batch 563, count: 2252 / 5078
# Batch 564, count: 2256 / 5078
# Batch 565, count: 2260 / 5078
# Batch 566, count: 2264 / 5078
# Batch 567, count: 2268 / 5078
# Batch 568, count: 2272 / 5078
# Batch 569, count: 2276 / 5078
# Batch 570, count: 2280 / 5078
# Batch 571, count: 2284 / 5078
# Batch 572, count: 2288 / 5078
# Batch 573, count: 2292 / 5078
# Batch 574, count: 2296 / 5078
# Batch 575, count: 2300 / 5078
# Batch 576, count: 2304 / 5078
# Batch 577, count: 2308 / 5078
# Batch 578, count: 2312 / 5078
# Batch 579, count: 2316 / 5078
# Batch 580, count: 2320 / 5078
# Batch 581, count: 2324 / 5078
# Batch 582, count: 2328 / 5078
# Batch 583, count: 2332 / 5078
# Batch 584, count: 2336 / 5078
# Batch 585, count: 2340 / 5078
# Batch 586, count: 2344 / 5078
# Batch 587, count: 2348 / 5078
# Batch 588, count: 2352 / 5078
# Batch 589, count: 2356 / 5078
# Batch 590, count: 2360 / 5078
# Batch 591, count: 2364 / 5078
# Batch 592, count: 2368 / 5078
# Batch 593, count: 2372 / 5078
# Batch 594, count: 2376 / 5078
# Batch 595, count: 2380 / 5078
# Batch 596, count: 2384 / 5078
# Batch 597, count: 2388 / 5078
# Batch 598, count: 2392 / 5078
# Batch 599, count: 2396 / 5078
# Batch 600, count: 2400 / 5078
# Batch 601, count: 2404 / 5078
# Batch 602, count: 2408 / 5078
# Batch 603, count: 2412 / 5078
# Batch 604, count: 2416 / 5078
# Batch 605, count: 2420 / 5078
# Batch 606, count: 2424 / 5078
# Batch 607, count: 2428 / 5078
# Batch 608, count: 2432 / 5078
# Batch 609, count: 2436 / 5078
# Batch 610, count: 2440 / 5078
# Batch 611, count: 2444 / 5078
# Batch 612, count: 2448 / 5078
# Batch 613, count: 2452 / 5078
# Batch 614, count: 2456 / 5078
# Batch 615, count: 2460 / 5078
# Batch 616, count: 2464 / 5078
# Batch 617, count: 2468 / 5078
# Batch 618, count: 2472 / 5078
# Batch 619, count: 2476 / 5078
# Batch 620, count: 2480 / 5078
# Batch 621, count: 2484 / 5078
# Batch 622, count: 2488 / 5078
# Batch 623, count: 2492 / 5078
# Batch 624, count: 2496 / 5078
# Batch 625, count: 2500 / 5078
# Batch 626, count: 2504 / 5078
# Batch 627, count: 2508 / 5078
# Batch 628, count: 2512 / 5078
# Batch 629, count: 2516 / 5078
# Batch 630, count: 2520 / 5078
# Batch 631, count: 2524 / 5078
# Batch 632, count: 2528 / 5078
# Batch 633, count: 2532 / 5078
# Batch 634, count: 2536 / 5078
# Batch 635, count: 2540 / 5078
# Batch 636, count: 2544 / 5078
# Batch 637, count: 2548 / 5078
# Batch 638, count: 2552 / 5078
# Batch 639, count: 2556 / 5078
# Batch 640, count: 2560 / 5078
# Batch 641, count: 2564 / 5078
# Batch 642, count: 2568 / 5078
# Batch 643, count: 2572 / 5078
# Batch 644, count: 2576 / 5078
# Batch 645, count: 2580 / 5078
# Batch 646, count: 2584 / 5078
# Batch 647, count: 2588 / 5078
# Batch 648, count: 2592 / 5078
# Batch 649, count: 2596 / 5078
# Batch 650, count: 2600 / 5078
# Batch 651, count: 2604 / 5078
# Batch 652, count: 2608 / 5078
# Batch 653, count: 2612 / 5078
# Batch 654, count: 2616 / 5078
# Batch 655, count: 2620 / 5078
# Batch 656, count: 2624 / 5078
# Batch 657, count: 2628 / 5078
# Batch 658, count: 2632 / 5078
# Batch 659, count: 2636 / 5078
# Batch 660, count: 2640 / 5078
# Batch 661, count: 2644 / 5078
# Batch 662, count: 2648 / 5078
# Batch 663, count: 2652 / 5078
# Batch 664, count: 2656 / 5078
# Batch 665, count: 2660 / 5078
# Batch 666, count: 2664 / 5078
# Batch 667, count: 2668 / 5078
# Batch 668, count: 2672 / 5078
# Batch 669, count: 2676 / 5078
# Batch 670, count: 2680 / 5078
# Batch 671, count: 2684 / 5078
# Batch 672, count: 2688 / 5078
# Batch 673, count: 2692 / 5078
# Batch 674, count: 2696 / 5078
# Batch 675, count: 2700 / 5078
# Batch 676, count: 2704 / 5078
# Batch 677, count: 2708 / 5078
# Batch 678, count: 2712 / 5078
# Batch 679, count: 2716 / 5078
# Batch 680, count: 2720 / 5078
# Batch 681, count: 2724 / 5078
# Batch 682, count: 2728 / 5078
# Batch 683, count: 2732 / 5078
# Batch 684, count: 2736 / 5078
# Batch 685, count: 2740 / 5078
# Batch 686, count: 2744 / 5078
# Batch 687, count: 2748 / 5078
# Batch 688, count: 2752 / 5078
# Batch 689, count: 2756 / 5078
# Batch 690, count: 2760 / 5078
# Batch 691, count: 2764 / 5078
# Batch 692, count: 2768 / 5078
# Batch 693, count: 2772 / 5078
# Batch 694, count: 2776 / 5078
# Batch 695, count: 2780 / 5078
# Batch 696, count: 2784 / 5078
# Batch 697, count: 2788 / 5078
# Batch 698, count: 2792 / 5078
# Batch 699, count: 2796 / 5078
# Batch 700, count: 2800 / 5078
# Batch 701, count: 2804 / 5078
# Batch 702, count: 2808 / 5078
# Batch 703, count: 2812 / 5078
# Batch 704, count: 2816 / 5078
# Batch 705, count: 2820 / 5078
# Batch 706, count: 2824 / 5078
# Batch 707, count: 2828 / 5078
# Batch 708, count: 2832 / 5078
# Batch 709, count: 2836 / 5078
# Batch 710, count: 2840 / 5078
# Batch 711, count: 2844 / 5078
# Batch 712, count: 2848 / 5078
# Batch 713, count: 2852 / 5078
# Batch 714, count: 2856 / 5078
# Batch 715, count: 2860 / 5078
# Batch 716, count: 2864 / 5078
# Batch 717, count: 2868 / 5078
# Batch 718, count: 2872 / 5078
# Batch 719, count: 2876 / 5078
# Batch 720, count: 2880 / 5078
# Batch 721, count: 2884 / 5078
# Batch 722, count: 2888 / 5078
# Batch 723, count: 2892 / 5078
# Batch 724, count: 2896 / 5078
# Batch 725, count: 2900 / 5078
# Batch 726, count: 2904 / 5078
# Batch 727, count: 2908 / 5078
# Batch 728, count: 2912 / 5078
# Batch 729, count: 2916 / 5078
# Batch 730, count: 2920 / 5078
# Batch 731, count: 2924 / 5078
# Batch 732, count: 2928 / 5078
# Batch 733, count: 2932 / 5078
# Batch 734, count: 2936 / 5078
# Batch 735, count: 2940 / 5078
# Batch 736, count: 2944 / 5078
# Batch 737, count: 2948 / 5078
# Batch 738, count: 2952 / 5078
# Batch 739, count: 2956 / 5078
# Batch 740, count: 2960 / 5078
# Batch 741, count: 2964 / 5078
# Batch 742, count: 2968 / 5078
# Batch 743, count: 2972 / 5078
# Batch 744, count: 2976 / 5078
# Batch 745, count: 2980 / 5078
# Batch 746, count: 2984 / 5078
# Batch 747, count: 2988 / 5078
# Batch 748, count: 2992 / 5078
# Batch 749, count: 2996 / 5078
# Batch 750, count: 3000 / 5078
# Batch 751, count: 3004 / 5078
# Batch 752, count: 3008 / 5078
# Batch 753, count: 3012 / 5078
# Batch 754, count: 3016 / 5078
# Batch 755, count: 3020 / 5078
# Batch 756, count: 3024 / 5078
# Batch 757, count: 3028 / 5078
# Batch 758, count: 3032 / 5078
# Batch 759, count: 3036 / 5078
# Batch 760, count: 3040 / 5078
# Batch 761, count: 3044 / 5078
# Batch 762, count: 3048 / 5078
# Batch 763, count: 3052 / 5078
# Batch 764, count: 3056 / 5078
# Batch 765, count: 3060 / 5078
# Batch 766, count: 3064 / 5078
# Batch 767, count: 3068 / 5078
# Batch 768, count: 3072 / 5078
# Batch 769, count: 3076 / 5078
# Batch 770, count: 3080 / 5078
# Batch 771, count: 3084 / 5078
# Batch 772, count: 3088 / 5078
# Batch 773, count: 3092 / 5078
# Batch 774, count: 3096 / 5078
# Batch 775, count: 3100 / 5078
# Batch 776, count: 3104 / 5078
# Batch 777, count: 3108 / 5078
# Batch 778, count: 3112 / 5078
# Batch 779, count: 3116 / 5078
# Batch 780, count: 3120 / 5078
# Batch 781, count: 3124 / 5078
# Batch 782, count: 3128 / 5078
# Batch 783, count: 3132 / 5078
# Batch 784, count: 3136 / 5078
# Batch 785, count: 3140 / 5078
# Batch 786, count: 3144 / 5078
# Batch 787, count: 3148 / 5078
# Batch 788, count: 3152 / 5078
# Batch 789, count: 3156 / 5078
# Batch 790, count: 3160 / 5078
# Batch 791, count: 3164 / 5078
# Batch 792, count: 3168 / 5078
# Batch 793, count: 3172 / 5078
# Batch 794, count: 3176 / 5078
# Batch 795, count: 3180 / 5078
# Batch 796, count: 3184 / 5078
# Batch 797, count: 3188 / 5078
# Batch 798, count: 3192 / 5078
# Batch 799, count: 3196 / 5078
# Batch 800, count: 3200 / 5078
# Batch 801, count: 3204 / 5078
# Batch 802, count: 3208 / 5078
# Batch 803, count: 3212 / 5078
# Batch 804, count: 3216 / 5078
# Batch 805, count: 3220 / 5078
# Batch 806, count: 3224 / 5078
# Batch 807, count: 3228 / 5078
# Batch 808, count: 3232 / 5078
# Batch 809, count: 3236 / 5078
# Batch 810, count: 3240 / 5078
# Batch 811, count: 3244 / 5078
# Batch 812, count: 3248 / 5078
# Batch 813, count: 3252 / 5078
# Batch 814, count: 3256 / 5078
# Batch 815, count: 3260 / 5078
# Batch 816, count: 3264 / 5078
# Batch 817, count: 3268 / 5078
# Batch 818, count: 3272 / 5078
# Batch 819, count: 3276 / 5078
# Batch 820, count: 3280 / 5078
# Batch 821, count: 3284 / 5078
# Batch 822, count: 3288 / 5078
# Batch 823, count: 3292 / 5078
# Batch 824, count: 3296 / 5078
# Batch 825, count: 3300 / 5078
# Batch 826, count: 3304 / 5078
# Batch 827, count: 3308 / 5078
# Batch 828, count: 3312 / 5078
# Batch 829, count: 3316 / 5078
# Batch 830, count: 3320 / 5078
# Batch 831, count: 3324 / 5078
# Batch 832, count: 3328 / 5078
# Batch 833, count: 3332 / 5078
# Batch 834, count: 3336 / 5078
# Batch 835, count: 3340 / 5078
# Batch 836, count: 3344 / 5078
# Batch 837, count: 3348 / 5078
# Batch 838, count: 3352 / 5078
# Batch 839, count: 3356 / 5078
# Batch 840, count: 3360 / 5078
# Batch 841, count: 3364 / 5078
# Batch 842, count: 3368 / 5078
# Batch 843, count: 3372 / 5078
# Batch 844, count: 3376 / 5078
# Batch 845, count: 3380 / 5078
# Batch 846, count: 3384 / 5078
# Batch 847, count: 3388 / 5078
# Batch 848, count: 3392 / 5078
# Batch 849, count: 3396 / 5078
# Batch 850, count: 3400 / 5078
# Batch 851, count: 3404 / 5078
# Batch 852, count: 3408 / 5078
# Batch 853, count: 3412 / 5078
# Batch 854, count: 3416 / 5078
# Batch 855, count: 3420 / 5078
# Batch 856, count: 3424 / 5078
# Batch 857, count: 3428 / 5078
# Batch 858, count: 3432 / 5078
# Batch 859, count: 3436 / 5078
# Batch 860, count: 3440 / 5078
# Batch 861, count: 3444 / 5078
# Batch 862, count: 3448 / 5078
# Batch 863, count: 3452 / 5078
# Batch 864, count: 3456 / 5078
# Batch 865, count: 3460 / 5078
# Batch 866, count: 3464 / 5078
# Batch 867, count: 3468 / 5078
# Batch 868, count: 3472 / 5078
# Batch 869, count: 3476 / 5078
# Batch 870, count: 3480 / 5078
# Batch 871, count: 3484 / 5078
# Batch 872, count: 3488 / 5078
# Batch 873, count: 3492 / 5078
# Batch 874, count: 3496 / 5078
# Batch 875, count: 3500 / 5078
# Batch 876, count: 3504 / 5078
# Batch 877, count: 3508 / 5078
# Batch 878, count: 3512 / 5078
# Batch 879, count: 3516 / 5078
# Batch 880, count: 3520 / 5078
# Batch 881, count: 3524 / 5078
# Batch 882, count: 3528 / 5078
# Batch 883, count: 3532 / 5078
# Batch 884, count: 3536 / 5078
# Batch 885, count: 3540 / 5078
# Batch 886, count: 3544 / 5078
# Batch 887, count: 3548 / 5078
# Batch 888, count: 3552 / 5078
# Batch 889, count: 3556 / 5078
# Batch 890, count: 3560 / 5078
# Batch 891, count: 3564 / 5078
# Batch 892, count: 3568 / 5078
# Batch 893, count: 3572 / 5078
# Batch 894, count: 3576 / 5078
# Batch 895, count: 3580 / 5078
# Batch 896, count: 3584 / 5078
# Batch 897, count: 3588 / 5078
# Batch 898, count: 3592 / 5078
# Batch 899, count: 3596 / 5078
# Batch 900, count: 3600 / 5078
# Batch 901, count: 3604 / 5078
# Batch 902, count: 3608 / 5078
# Batch 903, count: 3612 / 5078
# Batch 904, count: 3616 / 5078
# Batch 905, count: 3620 / 5078
# Batch 906, count: 3624 / 5078
# Batch 907, count: 3628 / 5078
# Batch 908, count: 3632 / 5078
# Batch 909, count: 3636 / 5078
# Batch 910, count: 3640 / 5078
# Batch 911, count: 3644 / 5078
# Batch 912, count: 3648 / 5078
# Batch 913, count: 3652 / 5078
# Batch 914, count: 3656 / 5078
# Batch 915, count: 3660 / 5078
# Batch 916, count: 3664 / 5078
# Batch 917, count: 3668 / 5078
# Batch 918, count: 3672 / 5078
# Batch 919, count: 3676 / 5078
# Batch 920, count: 3680 / 5078
# Batch 921, count: 3684 / 5078
# Batch 922, count: 3688 / 5078
# Batch 923, count: 3692 / 5078
# Batch 924, count: 3696 / 5078
# Batch 925, count: 3700 / 5078
# Batch 926, count: 3704 / 5078
# Batch 927, count: 3708 / 5078
# Batch 928, count: 3712 / 5078
# Batch 929, count: 3716 / 5078
# Batch 930, count: 3720 / 5078
# Batch 931, count: 3724 / 5078
# Batch 932, count: 3728 / 5078
# Batch 933, count: 3732 / 5078
# Batch 934, count: 3736 / 5078
# Batch 935, count: 3740 / 5078
# Batch 936, count: 3744 / 5078
# Batch 937, count: 3748 / 5078
# Batch 938, count: 3752 / 5078
# Batch 939, count: 3756 / 5078
# Batch 940, count: 3760 / 5078
# Batch 941, count: 3764 / 5078
# Batch 942, count: 3768 / 5078
# Batch 943, count: 3772 / 5078
# Batch 944, count: 3776 / 5078
# Batch 945, count: 3780 / 5078
# Batch 946, count: 3784 / 5078
# Batch 947, count: 3788 / 5078
# Batch 948, count: 3792 / 5078
# Batch 949, count: 3796 / 5078
# Batch 950, count: 3800 / 5078
# Batch 951, count: 3804 / 5078
# Batch 952, count: 3808 / 5078
# Batch 953, count: 3812 / 5078
# Batch 954, count: 3816 / 5078
# Batch 955, count: 3820 / 5078
# Batch 956, count: 3824 / 5078
# Batch 957, count: 3828 / 5078
# Batch 958, count: 3832 / 5078
# Batch 959, count: 3836 / 5078
# Batch 960, count: 3840 / 5078
# Batch 961, count: 3844 / 5078
# Batch 962, count: 3848 / 5078
# Batch 963, count: 3852 / 5078
# Batch 964, count: 3856 / 5078
# Batch 965, count: 3860 / 5078
# Batch 966, count: 3864 / 5078
# Batch 967, count: 3868 / 5078
# Batch 968, count: 3872 / 5078
# Batch 969, count: 3876 / 5078
# Batch 970, count: 3880 / 5078
# Batch 971, count: 3884 / 5078
# Batch 972, count: 3888 / 5078
# Batch 973, count: 3892 / 5078
# Batch 974, count: 3896 / 5078
# Batch 975, count: 3900 / 5078
# Batch 976, count: 3904 / 5078
# Batch 977, count: 3908 / 5078
# Batch 978, count: 3912 / 5078
# Batch 979, count: 3916 / 5078
# Batch 980, count: 3920 / 5078
# Batch 981, count: 3924 / 5078
# Batch 982, count: 3928 / 5078
# Batch 983, count: 3932 / 5078
# Batch 984, count: 3936 / 5078
# Batch 985, count: 3940 / 5078
# Batch 986, count: 3944 / 5078
# Batch 987, count: 3948 / 5078
# Batch 988, count: 3952 / 5078
# Batch 989, count: 3956 / 5078
# Batch 990, count: 3960 / 5078
# Batch 991, count: 3964 / 5078
# Batch 992, count: 3968 / 5078
# Batch 993, count: 3972 / 5078
# Batch 994, count: 3976 / 5078
# Batch 995, count: 3980 / 5078
# Batch 996, count: 3984 / 5078
# Batch 997, count: 3988 / 5078
# Batch 998, count: 3992 / 5078
# Batch 999, count: 3996 / 5078
# Batch 1000, count: 4000 / 5078
# Batch 1001, count: 4004 / 5078
# Batch 1002, count: 4008 / 5078
# Batch 1003, count: 4012 / 5078
# Batch 1004, count: 4016 / 5078
# Batch 1005, count: 4020 / 5078
# Batch 1006, count: 4024 / 5078
# Batch 1007, count: 4028 / 5078
# Batch 1008, count: 4032 / 5078
# Batch 1009, count: 4036 / 5078
# Batch 1010, count: 4040 / 5078
# Batch 1011, count: 4044 / 5078
# Batch 1012, count: 4048 / 5078
# Batch 1013, count: 4052 / 5078
# Batch 1014, count: 4056 / 5078
# Batch 1015, count: 4060 / 5078
# Batch 1016, count: 4064 / 5078
# Batch 1017, count: 4068 / 5078
# Batch 1018, count: 4072 / 5078
# Batch 1019, count: 4076 / 5078
# Batch 1020, count: 4080 / 5078
# Batch 1021, count: 4084 / 5078
# Batch 1022, count: 4088 / 5078
# Batch 1023, count: 4092 / 5078
# Batch 1024, count: 4096 / 5078
# Batch 1025, count: 4100 / 5078
# Batch 1026, count: 4104 / 5078
# Batch 1027, count: 4108 / 5078
# Batch 1028, count: 4112 / 5078
# Batch 1029, count: 4116 / 5078
# Batch 1030, count: 4120 / 5078
# Batch 1031, count: 4124 / 5078
# Batch 1032, count: 4128 / 5078
# Batch 1033, count: 4132 / 5078
# Batch 1034, count: 4136 / 5078
# Batch 1035, count: 4140 / 5078
# Batch 1036, count: 4144 / 5078
# Batch 1037, count: 4148 / 5078
# Batch 1038, count: 4152 / 5078
# Batch 1039, count: 4156 / 5078
# Batch 1040, count: 4160 / 5078
# Batch 1041, count: 4164 / 5078
# Batch 1042, count: 4168 / 5078
# Batch 1043, count: 4172 / 5078
# Batch 1044, count: 4176 / 5078
# Batch 1045, count: 4180 / 5078
# Batch 1046, count: 4184 / 5078
# Batch 1047, count: 4188 / 5078
# Batch 1048, count: 4192 / 5078
# Batch 1049, count: 4196 / 5078
# Batch 1050, count: 4200 / 5078
# Batch 1051, count: 4204 / 5078
# Batch 1052, count: 4208 / 5078
# Batch 1053, count: 4212 / 5078
# Batch 1054, count: 4216 / 5078
# Batch 1055, count: 4220 / 5078
# Batch 1056, count: 4224 / 5078
# Batch 1057, count: 4228 / 5078
# Batch 1058, count: 4232 / 5078
# Batch 1059, count: 4236 / 5078
# Batch 1060, count: 4240 / 5078
# Batch 1061, count: 4244 / 5078
# Batch 1062, count: 4248 / 5078
# Batch 1063, count: 4252 / 5078
# Batch 1064, count: 4256 / 5078
# Batch 1065, count: 4260 / 5078
# Batch 1066, count: 4264 / 5078
# Batch 1067, count: 4268 / 5078
# Batch 1068, count: 4272 / 5078
# Batch 1069, count: 4276 / 5078
# Batch 1070, count: 4280 / 5078
# Batch 1071, count: 4284 / 5078
# Batch 1072, count: 4288 / 5078
# Batch 1073, count: 4292 / 5078
# Batch 1074, count: 4296 / 5078
# Batch 1075, count: 4300 / 5078
# Batch 1076, count: 4304 / 5078
# Batch 1077, count: 4308 / 5078
# Batch 1078, count: 4312 / 5078
# Batch 1079, count: 4316 / 5078
# Batch 1080, count: 4320 / 5078
# Batch 1081, count: 4324 / 5078
# Batch 1082, count: 4328 / 5078
# Batch 1083, count: 4332 / 5078
# Batch 1084, count: 4336 / 5078
# Batch 1085, count: 4340 / 5078
# Batch 1086, count: 4344 / 5078
# Batch 1087, count: 4348 / 5078
# Batch 1088, count: 4352 / 5078
# Batch 1089, count: 4356 / 5078
# Batch 1090, count: 4360 / 5078
# Batch 1091, count: 4364 / 5078
# Batch 1092, count: 4368 / 5078
# Batch 1093, count: 4372 / 5078
# Batch 1094, count: 4376 / 5078
# Batch 1095, count: 4380 / 5078
# Batch 1096, count: 4384 / 5078
# Batch 1097, count: 4388 / 5078
# Batch 1098, count: 4392 / 5078
# Batch 1099, count: 4396 / 5078
# Batch 1100, count: 4400 / 5078
# Batch 1101, count: 4404 / 5078
# Batch 1102, count: 4408 / 5078
# Batch 1103, count: 4412 / 5078
# Batch 1104, count: 4416 / 5078
# Batch 1105, count: 4420 / 5078
# Batch 1106, count: 4424 / 5078
# Batch 1107, count: 4428 / 5078
# Batch 1108, count: 4432 / 5078
# Batch 1109, count: 4436 / 5078
# Batch 1110, count: 4440 / 5078
# Batch 1111, count: 4444 / 5078
# Batch 1112, count: 4448 / 5078
# Batch 1113, count: 4452 / 5078
# Batch 1114, count: 4456 / 5078
# Batch 1115, count: 4460 / 5078
# Batch 1116, count: 4464 / 5078
# Batch 1117, count: 4468 / 5078
# Batch 1118, count: 4472 / 5078
# Batch 1119, count: 4476 / 5078
# Batch 1120, count: 4480 / 5078
# Batch 1121, count: 4484 / 5078
# Batch 1122, count: 4488 / 5078
# Batch 1123, count: 4492 / 5078
# Batch 1124, count: 4496 / 5078
# Batch 1125, count: 4500 / 5078
# Batch 1126, count: 4504 / 5078
# Batch 1127, count: 4508 / 5078
# Batch 1128, count: 4512 / 5078
# Batch 1129, count: 4516 / 5078
# Batch 1130, count: 4520 / 5078
# Batch 1131, count: 4524 / 5078
# Batch 1132, count: 4528 / 5078
# Batch 1133, count: 4532 / 5078
# Batch 1134, count: 4536 / 5078
# Batch 1135, count: 4540 / 5078
# Batch 1136, count: 4544 / 5078
# Batch 1137, count: 4548 / 5078
# Batch 1138, count: 4552 / 5078
# Batch 1139, count: 4556 / 5078
# Batch 1140, count: 4560 / 5078
# Batch 1141, count: 4564 / 5078
# Batch 1142, count: 4568 / 5078
# Batch 1143, count: 4572 / 5078
# Batch 1144, count: 4576 / 5078
# Batch 1145, count: 4580 / 5078
# Batch 1146, count: 4584 / 5078
# Batch 1147, count: 4588 / 5078
# Batch 1148, count: 4592 / 5078
# Batch 1149, count: 4596 / 5078
# Batch 1150, count: 4600 / 5078
# Batch 1151, count: 4604 / 5078
# Batch 1152, count: 4608 / 5078
# Batch 1153, count: 4612 / 5078
# Batch 1154, count: 4616 / 5078
# Batch 1155, count: 4620 / 5078
# Batch 1156, count: 4624 / 5078
# Batch 1157, count: 4628 / 5078
# Batch 1158, count: 4632 / 5078
# Batch 1159, count: 4636 / 5078
# Batch 1160, count: 4640 / 5078
# Batch 1161, count: 4644 / 5078
# Batch 1162, count: 4648 / 5078
# Batch 1163, count: 4652 / 5078
# Batch 1164, count: 4656 / 5078
# Batch 1165, count: 4660 / 5078
# Batch 1166, count: 4664 / 5078
# Batch 1167, count: 4668 / 5078
# Batch 1168, count: 4672 / 5078
# Batch 1169, count: 4676 / 5078
# Batch 1170, count: 4680 / 5078
# Batch 1171, count: 4684 / 5078
# Batch 1172, count: 4688 / 5078
# Batch 1173, count: 4692 / 5078
# Batch 1174, count: 4696 / 5078
# Batch 1175, count: 4700 / 5078
# Batch 1176, count: 4704 / 5078
# Batch 1177, count: 4708 / 5078
# Batch 1178, count: 4712 / 5078
# Batch 1179, count: 4716 / 5078
# Batch 1180, count: 4720 / 5078
# Batch 1181, count: 4724 / 5078
# Batch 1182, count: 4728 / 5078
# Batch 1183, count: 4732 / 5078
# Batch 1184, count: 4736 / 5078
# Batch 1185, count: 4740 / 5078
# Batch 1186, count: 4744 / 5078
# Batch 1187, count: 4748 / 5078
# Batch 1188, count: 4752 / 5078
# Batch 1189, count: 4756 / 5078
# Batch 1190, count: 4760 / 5078
# Batch 1191, count: 4764 / 5078
# Batch 1192, count: 4768 / 5078
# Batch 1193, count: 4772 / 5078
# Batch 1194, count: 4776 / 5078
# Batch 1195, count: 4780 / 5078
# Batch 1196, count: 4784 / 5078
# Batch 1197, count: 4788 / 5078
# Batch 1198, count: 4792 / 5078
# Batch 1199, count: 4796 / 5078
# Batch 1200, count: 4800 / 5078
# Batch 1201, count: 4804 / 5078
# Batch 1202, count: 4808 / 5078
# Batch 1203, count: 4812 / 5078
# Batch 1204, count: 4816 / 5078
# Batch 1205, count: 4820 / 5078
# Batch 1206, count: 4824 / 5078
# Batch 1207, count: 4828 / 5078
# Batch 1208, count: 4832 / 5078
# Batch 1209, count: 4836 / 5078
# Batch 1210, count: 4840 / 5078
# Batch 1211, count: 4844 / 5078
# Batch 1212, count: 4848 / 5078
# Batch 1213, count: 4852 / 5078
# Batch 1214, count: 4856 / 5078
# Batch 1215, count: 4860 / 5078
# Batch 1216, count: 4864 / 5078
# Batch 1217, count: 4868 / 5078
# Batch 1218, count: 4872 / 5078
# Batch 1219, count: 4876 / 5078
# Batch 1220, count: 4880 / 5078
# Batch 1221, count: 4884 / 5078
# Batch 1222, count: 4888 / 5078
# Batch 1223, count: 4892 / 5078
# Batch 1224, count: 4896 / 5078
# Batch 1225, count: 4900 / 5078
# Batch 1226, count: 4904 / 5078
# Batch 1227, count: 4908 / 5078
# Batch 1228, count: 4912 / 5078
# Batch 1229, count: 4916 / 5078
# Batch 1230, count: 4920 / 5078
# Batch 1231, count: 4924 / 5078
# Batch 1232, count: 4928 / 5078
# Batch 1233, count: 4932 / 5078
# Batch 1234, count: 4936 / 5078
# Batch 1235, count: 4940 / 5078
# Batch 1236, count: 4944 / 5078
# Batch 1237, count: 4948 / 5078
# Batch 1238, count: 4952 / 5078
# Batch 1239, count: 4956 / 5078
# Batch 1240, count: 4960 / 5078
# Batch 1241, count: 4964 / 5078
# Batch 1242, count: 4968 / 5078
# Batch 1243, count: 4972 / 5078
# Batch 1244, count: 4976 / 5078
# Batch 1245, count: 4980 / 5078
# Batch 1246, count: 4984 / 5078
# Batch 1247, count: 4988 / 5078
# Batch 1248, count: 4992 / 5078
# Batch 1249, count: 4996 / 5078
# Batch 1250, count: 5000 / 5078
# Batch 1251, count: 5004 / 5078
# Batch 1252, count: 5008 / 5078
# Batch 1253, count: 5012 / 5078
# Batch 1254, count: 5016 / 5078
# Batch 1255, count: 5020 / 5078
# Batch 1256, count: 5024 / 5078
# Batch 1257, count: 5028 / 5078
# Batch 1258, count: 5032 / 5078
# Batch 1259, count: 5036 / 5078
# Batch 1260, count: 5040 / 5078
# Batch 1261, count: 5044 / 5078
# Batch 1262, count: 5048 / 5078
# Batch 1263, count: 5052 / 5078
# Batch 1264, count: 5056 / 5078
# Batch 1265, count: 5060 / 5078
# Batch 1266, count: 5064 / 5078
# Batch 1267, count: 5068 / 5078
# Batch 1268, count: 5072 / 5078
# Batch 1269, count: 5076 / 5078
