# %%
import json
import cv2
import numpy as np

from dataclasses import dataclass

from PIL import Image
from IPython import display

import os
import shutil

from typing import Optional
from __future__ import annotations

# %%
@dataclass
class Joint:
    parent: Optional[Joint]
    x: float
    y: float
    confidence: float
    
    def is_empty(self):
        return self.x == 0 and self.y == 0 and self.confidence == 0

# %%
joint_colours = np.linspace(0, 179, 26)[:-1]
joint_colours = np.array([(round(h), 255, 255) for h in joint_colours]).astype(np.uint8)
joint_colours = joint_colours[np.newaxis, ...]
joint_colours = cv2.cvtColor(joint_colours, cv2.COLOR_HSV2BGR)
joint_colours = joint_colours.squeeze().astype(int)
joint_colours = [tuple([int(x) for x in joint_colour]) for joint_colour in joint_colours]

# %%
joint_connections = {
    "nose": None,
    "neck": "nose",
    "right_shoulder": "neck",
    "right_elbow": "right_shoulder",
    "right_wrist": "right_elbow",
    "left_shoulder": "neck",
    "left_elbow": "left_shoulder",
    "left_wrist": "left_elbow",
    "mid_hip": "neck",
    "right_hip": "mid_hip",
    "right_knee": "right_hip",
    "right_ankle": "right_knee",
    "left_hip": "mid_hip",
    "left_knee": "left_hip",
    "left_ankle": "left_knee",
    "right_eye": "nose",
    "left_eye": "nose",
    "right_ear": "right_eye",
    "left_ear": "left_eye",
    "left_big_toe": "left_ankle",
    "left_small_toe": "left_big_toe",
    "left_heel": "left_ankle",
    "right_big_toe": "right_ankle",
    "right_small_toe": "right_big_toe",
    "right_heel": "right_ankle"
}

# %%
# https://github.com/CMU-Perceptual-Computing-Lab/openpose/blob/master/doc/02_output.md

@dataclass
class PoseKeypoints:
    nose: Joint
    neck: Joint
    right_shoulder: Joint
    right_elbow: Joint
    right_wrist: Joint
    left_shoulder: Joint
    left_elbow: Joint
    left_wrist: Joint
    mid_hip: Joint
    right_hip: Joint
    right_knee: Joint
    right_ankle: Joint
    left_hip: Joint
    left_knee: Joint
    left_ankle: Joint
    right_eye: Joint
    left_eye: Joint
    right_ear: Joint
    left_ear: Joint
    left_big_toe: Joint
    left_small_toe: Joint
    left_heel: Joint
    right_big_toe: Joint
    right_small_toe: Joint
    right_heel: Joint
    
    def get_empty_joints(self):
        return {joint_name: getattr(self, joint_name) for joint_name in self.__annotations__.keys() if getattr(self, joint_name).is_empty()}
    
    def overlay_pose(self, frame):
        mapping = list(PoseKeypoints.__dict__["__annotations__"].keys())
        pose_overlayed_frame = frame.copy()
        height, width, channels = pose_overlayed_frame.shape

        for i, joint_name in enumerate(self.__annotations__.keys()):
            joint = getattr(self, joint_name)

            if joint.is_empty(): 
                continue
            
            joint_pos = (round(joint.x * width), round(joint.y * height))
            cv2.circle(pose_overlayed_frame, joint_pos, radius=1, color=joint_colours[i], thickness=2)
            cv2.putText(pose_overlayed_frame, mapping[i], (round(joint.x * width), round(joint.y * (height - 0.02))), cv2.FONT_HERSHEY_SIMPLEX, 0.5, joint_colours[i], 1, cv2.LINE_AA)
            
            if joint.parent is not None and not joint.parent.is_empty():
                parent_pos = (round(joint.parent.x * width), round(joint.parent.y * height))
                cv2.line(pose_overlayed_frame, joint_pos, parent_pos, joint_colours[i], thickness=1)
        
        return pose_overlayed_frame
    
    def head_visibility_score(self):
        # 0 = not visible, 1 = completely visible
        parts = {"nose", "left_eye", "left_ear", "right_eye", "right_ear"}
        empty_parts = set(self.get_empty_joints().keys())
        visible_parts = parts - empty_parts
        return len(visible_parts) / len(parts)
    
    def torso_arms_visibility_score(self):
        # 0 = not visible, 1 = completely visible
        parts = {"neck", "left_shoulder", "left_elbow", "left_wrist", "right_shoulder", "right_elbow", "right_wrist"}
        empty_parts = set(self.get_empty_joints().keys())
        visible_parts = parts - empty_parts
        return len(visible_parts) / len(parts)
    
    def hip_visibility_score(self):
        # 0 = not visible, 1 = completely visible
        parts = {"mid_hip", "left_hip", "right_hip"}
        empty_parts = set(self.get_empty_joints().keys())
        visible_parts = parts - empty_parts
        return len(visible_parts) / len(parts)
    
    def legs_visibility_score(self):
        # 0 = not visible, 1 = completely visible
        parts = {"left_knee", "left_ankle", "right_knee", "right_ankle"}
        empty_parts = set(self.get_empty_joints().keys())
        visible_parts = parts - empty_parts
        return len(visible_parts) / len(parts)
    
    def feet_visibility_score(self):
        # 0 = not visible, 1 = completely visible
        parts = {"left_ankle", "left_heel", "left_big_toe", "left_small_toe", "right_ankle", "right_heel", "right_big_toe", "right_small_toe"}
        empty_parts = set(self.get_empty_joints().keys())
        visible_parts = parts - empty_parts
        return len(visible_parts) / len(parts)
    
    def knee_angles(self):
        left_ratio = None
        right_ratio = None
        
        # we can estimate if someone is sitting by looking at the angle of their knee to the hip
        # note left_hip > left_knee but left_hip.y < left_knee.y due to the way coords are done in these images
        
        if not self.left_hip.is_empty() and not self.left_knee.is_empty():
            left_opp = -self.left_hip.y + self.left_knee.y
            left_adj = abs(self.left_hip.x - self.left_knee.x)
            
            left_ratio = np.rad2deg(np.arctan2(left_opp, left_adj))
            
        if not self.right_hip.is_empty() and not self.right_knee.is_empty():
            right_opp = -self.right_hip.y + self.right_knee.y
            right_adj = abs(self.right_hip.x - self.right_knee.x)
            
            right_ratio = np.rad2deg(np.arctan2(right_opp, right_adj))
        
        return left_ratio, right_ratio
    
    def classify_general_pose(self):
        head_score = self.head_visibility_score()
        ta_score = self.torso_arms_visibility_score()
        hip_score = self.hip_visibility_score()
        legs_score = self.legs_visibility_score()
        feet_score = self.feet_visibility_score()
        
        if head_score >= 0.6 and ta_score <= 0.45 and hip_score + legs_score + feet_score == 0:
            return "Head Only"
        
        # hip_score >= 0 redundant
        if head_score >= 0.4 and ta_score >= 0.5 and hip_score >= 0 and legs_score + feet_score == 0: 
            return "Half Body"
        
        # feet_score >= 0 redundant
        if head_score >= 0.4 and ta_score >= 0.7 and hip_score >= 0.5 and legs_score >= 0.5 and feet_score >= 0:
            return "Full Body"
        
        return "Other"
        
    def is_sitting(self):
        left_angle, right_angle = self.knee_angles()
        
        if left_angle is None and right_angle is None:
            return "Other"
        
        if left_angle is not None:
            if left_angle < 0:
                return "Other"
        
        if right_angle is not None:
            if right_angle < 0:
                return "Other"
            
        angle_threshold = 50
        
        left_sitting = None if left_angle is None else left_angle < angle_threshold
        right_sitting = None if right_angle is None else right_angle < angle_threshold
        
        if left_sitting is not None and right_sitting is not None:
            # As long as one says they are sitting, we take it to be that they are sitting
            return "Sitting" if left_sitting or right_sitting else "Standing"
        
        if left_sitting is not None:
            return "Sitting" if left_sitting else "Standing"
        
        if right_sitting is not None:
            return "Sitting" if right_sitting else "Standing"
    
    def classify(self):
        general_pose = self.classify_general_pose()
        
        if general_pose != "Full Body":
            return general_pose
        
        position = self.is_sitting()
        
        if position == "Other":
            return "Other"
        
        return f"Full Body {position}"
    
    @staticmethod
    def load_keypoints(raw_kps):
        mapping = list(PoseKeypoints.__dict__["__annotations__"].keys())
        points_as_dict = {}
        
        for i, part in enumerate(mapping):
            if joint_connections[part] is None:
                points_as_dict[part] = Joint(None, raw_kps[3 * i], raw_kps[3 * i + 1], raw_kps[3 * i + 2])
            else:
                points_as_dict[part] = Joint(points_as_dict[joint_connections[part]], raw_kps[3 * i], raw_kps[3 * i + 1], raw_kps[3 * i + 2])
        
        return PoseKeypoints(**points_as_dict)

# %%
in_frame_folder = "./output/segmented/Train/Game"
in_pose_folder = "./output/segmented/Train/Game/openpose_out_normalised"
out_folder = "./output/pose_classified_game"
show_skeleton = False

# %%
file_names = []

for file in os.listdir(in_frame_folder):
    path = f"{in_frame_folder}/{file}"
    
    if not os.path.isfile(path):
        continue
        
    file_names.append(''.join(file.split(".")[:-1]))

len(file_names)
# Out:
# 12217

# %%
for file in file_names:
    frame_loc = f"{in_frame_folder}/{file}.jpg"
    keypoints_loc = f"{in_pose_folder}/{file}_keypoints.json"
    
    with open(keypoints_loc, "r") as fp:
        raw_data = json.load(fp)
    
    if len(raw_data["people"]) != 1:
        # print(frame_loc)
        continue
    
    print(frame_loc)
    
    kps = raw_data["people"][0]["pose_keypoints_2d"]
    pose = PoseKeypoints.load_keypoints(kps)
    
    classification = pose.classify()
    save_loc = f"{out_folder}/{classification}/{file}.jpg"
    
    frame = cv2.imread(frame_loc)
    
    if show_skeleton:
        frame = pose.overlay_pose(frame)
    
    print(classification)
    
    cv2.imwrite(save_loc, frame)
# Out:
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00001_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00001_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00002_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00002_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00003_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00003_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00004_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00004_1.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00005_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00005_1.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00006_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00006_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00007_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00007_1.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00008_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00009_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00010_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00011_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00012_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00013_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00014_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00015_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00016_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00017_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00018_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00019_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00020_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00021_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00022_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00023_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00024_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00025_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00026_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00027_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00028_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00029_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00030_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00031_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00032_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00033_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00034_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00035_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00036_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00037_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00038_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00039_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00040_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00041_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00042_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00043_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00044_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00045_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00046_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00047_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00048_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00049_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00050_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00051_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00052_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00053_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00054_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00055_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00056_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00057_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00058_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00059_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00060_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00061_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00062_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00063_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00064_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00065_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00066_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00067_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00068_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00069_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00070_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00071_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00072_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00073_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00074_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00075_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00076_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00077_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00078_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00079_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00080_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00081_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00082_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00083_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00084_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00085_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00086_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00087_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00088_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00089_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00090_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00091_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00092_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00093_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00094_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00095_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00096_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00097_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00098_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00099_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00100_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00101_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00102_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00103_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00104_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00109_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00110_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00111_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00112_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00113_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00114_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00115_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00116_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00117_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00118_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00119_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00120_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00121_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00122_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00123_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00124_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00125_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00126_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00127_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00128_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00129_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00130_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00131_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00132_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00133_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00134_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00135_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00136_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00137_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00138_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00139_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00140_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00141_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00142_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00143_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00144_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00145_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00146_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00147_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00148_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00149_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00150_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00151_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00152_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00153_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00154_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00155_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00156_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00157_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00158_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00159_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00160_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00161_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00162_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00163_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00164_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00165_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00166_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00167_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00168_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00169_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00170_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00171_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00172_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00173_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00174_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00175_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00176_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00177_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00178_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00179_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00180_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00181_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00182_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00183_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00184_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00185_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00186_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00187_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00188_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00189_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00190_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00191_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00192_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00193_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00194_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00195_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00196_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00197_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00198_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00199_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00200_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00201_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00202_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00203_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00204_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00205_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00206_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00207_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00208_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00209_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00210_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00211_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00212_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00213_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00214_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00215_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00216_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00217_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00218_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00218_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00219_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00219_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00220_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00220_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00221_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00221_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00222_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00223_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00224_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00225_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00226_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00227_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00228_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00229_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00230_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00231_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00232_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00233_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00234_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00235_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00236_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00237_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00238_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00238_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00239_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00239_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00240_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00241_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00242_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00242_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00243_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00243_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00244_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00244_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00245_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00246_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00246_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00247_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00247_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00248_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00248_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00249_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00250_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00251_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00252_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00252_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00253_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00254_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00255_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00256_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00257_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00258_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00259_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00259_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00260_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00260_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00261_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00262_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00262_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00263_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00263_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00264_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00265_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00266_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00267_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00268_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00269_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00270_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00271_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00272_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00272_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00273_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00273_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00274_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00274_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00275_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00275_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00276_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00277_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00278_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00279_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00279_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00280_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00280_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00281_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00282_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00283_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00284_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00285_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00286_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00287_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00288_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00289_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00289_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00290_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00290_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00291_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00291_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00292_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00293_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00294_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00295_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00297_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00297_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00299_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00299_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00300_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00301_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00303_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00304_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00305_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00306_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00307_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00308_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00309_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00310_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00311_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00312_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00313_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00314_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00315_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00316_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00317_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00318_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00319_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00320_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00321_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00322_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00323_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00324_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00325_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00326_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00327_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00328_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00329_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00330_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00331_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00332_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00333_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00334_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00335_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00336_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00337_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00338_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00339_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00340_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00341_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00342_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00343_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00344_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00345_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00346_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00347_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00348_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00349_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00350_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00351_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00352_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00353_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00354_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00355_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00356_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00357_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00358_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00359_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00360_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00361_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00362_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00363_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00364_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00365_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00366_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00367_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00368_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00369_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00370_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00371_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00372_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00373_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00374_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00375_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00376_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00377_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00378_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00379_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00380_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00381_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00382_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00383_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00384_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00385_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00386_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00387_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00388_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00389_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00390_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00391_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00392_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00393_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00394_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00395_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00396_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00397_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00398_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00399_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00400_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00401_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00402_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00403_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00404_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00405_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00406_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00407_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00408_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00410_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00412_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00413_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00415_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00416_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00417_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00418_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00419_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00420_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00424_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00425_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00426_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00426_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00427_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00428_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00429_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00430_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00431_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00433_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00434_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00438_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00440_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00442_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00444_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00445_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00446_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00447_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00448_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00449_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00450_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00451_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00452_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00453_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00454_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00455_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00456_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00457_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00458_0.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00459_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00460_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00463_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00464_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00465_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00467_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00468_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00468_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00469_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00470_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00473_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00475_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00476_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00477_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00479_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00479_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00480_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00480_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00481_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00482_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00483_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00483_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00484_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00484_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00485_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00485_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00486_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00486_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00487_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00487_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00488_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00488_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00489_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00489_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00490_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00491_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00492_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00493_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00494_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00495_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00495_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00496_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00497_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00497_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00498_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00498_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00499_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00499_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00500_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00500_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00501_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00501_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00502_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00502_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00503_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00503_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00504_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00504_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00505_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00505_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00506_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00506_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00507_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00507_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00508_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00508_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00509_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00509_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00510_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00510_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00511_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00511_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00512_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00512_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00513_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00513_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00514_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00514_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00515_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00515_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00516_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00516_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00517_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00517_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00518_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00518_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00519_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00519_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00520_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00520_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00521_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00521_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00522_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00522_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00523_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00523_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00524_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00524_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00525_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00525_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00526_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00526_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00527_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00527_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00528_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00528_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00529_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00529_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00530_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00530_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00531_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00531_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00532_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00532_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00533_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00533_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00534_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00534_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00535_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00535_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00536_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00536_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00537_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00537_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00538_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00538_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00539_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00539_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00540_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00540_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00541_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00541_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00542_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00542_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00543_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00544_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00545_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00545_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00546_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00547_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_01_00548_0.jpg
# Half Body
# ...
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00261_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00262_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00263_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00264_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00264_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00265_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00265_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00266_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00266_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00267_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00267_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00268_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00268_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00269_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00269_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00270_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00271_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00271_2.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00272_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00272_1.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00272_2.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00273_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00273_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00273_2.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00274_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00274_1.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00275_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00276_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00276_2.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00277_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00279_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00279_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00280_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00281_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00282_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00283_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00284_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00288_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00290_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00292_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00293_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00294_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00294_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00295_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00295_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00296_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00296_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00297_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00297_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00298_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00299_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00300_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00301_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00302_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00303_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00304_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00305_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00306_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00307_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00308_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00309_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00310_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00311_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00312_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00313_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00314_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00315_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00316_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00317_0.jpg
# Full Body Standing
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00318_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00319_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00320_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00321_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00322_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00323_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00324_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00325_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00326_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00327_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00328_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00329_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00330_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00331_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00332_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00333_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00334_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00335_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00336_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00337_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00338_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00339_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00340_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00341_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00342_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00343_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00344_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00344_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00345_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00345_1.jpg
# Head Only
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00346_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00346_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00347_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00347_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00348_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00348_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00349_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00349_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00350_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00350_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00351_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00352_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00353_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00354_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00355_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00356_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00357_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00358_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00359_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00360_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00361_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00362_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00362_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00363_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00363_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00364_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00365_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00365_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00366_1.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00367_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00368_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00368_2.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00369_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00370_1.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00370_2.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00371_1.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00371_2.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00372_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00372_2.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00373_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00374_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00375_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00376_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00377_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00378_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00379_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00380_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00381_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00382_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00382_2.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00383_1.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00384_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00385_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00385_2.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00386_1.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00387_1.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00387_2.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00388_1.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00388_2.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00389_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00389_2.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00390_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00391_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00391_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00392_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00392_2.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00393_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00394_1.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00394_2.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00395_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00395_2.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00396_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00396_2.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00397_0.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00397_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00397_2.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00398_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00398_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00399_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00399_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00399_2.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00400_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00400_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00400_2.jpg
# Other
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00401_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00401_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00401_2.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00402_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00402_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00403_0.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00403_1.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00403_2.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00404_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00404_1.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00404_2.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00405_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00405_1.jpg
# Full Body Sitting
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00406_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00406_2.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00407_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00408_0.jpg
# Half Body
# ./output/segmented/Train/Game/Segmented_Train_Game_10_00409_0.jpg
# Half Body
