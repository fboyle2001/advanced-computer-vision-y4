# %%
import json
import cv2
import numpy as np

from dataclasses import dataclass

from PIL import Image
from IPython import display

import os
import shutil

from typing import Optional
from __future__ import annotations

# %%
@dataclass
class Joint:
    parent: Optional[Joint]
    x: float
    y: float
    confidence: float
    
    def is_empty(self):
        return self.x == 0 and self.y == 0 and self.confidence == 0

# %%
joint_colours = np.linspace(0, 179, 26)[:-1]
joint_colours = np.array([(round(h), 255, 255) for h in joint_colours]).astype(np.uint8)
joint_colours = joint_colours[np.newaxis, ...]
joint_colours = cv2.cvtColor(joint_colours, cv2.COLOR_HSV2BGR)
joint_colours = joint_colours.squeeze().astype(int)
joint_colours = [tuple([int(x) for x in joint_colour]) for joint_colour in joint_colours]

# %%
joint_connections = {
    "nose": None,
    "neck": "nose",
    "right_shoulder": "neck",
    "right_elbow": "right_shoulder",
    "right_wrist": "right_elbow",
    "left_shoulder": "neck",
    "left_elbow": "left_shoulder",
    "left_wrist": "left_elbow",
    "mid_hip": "neck",
    "right_hip": "mid_hip",
    "right_knee": "right_hip",
    "right_ankle": "right_knee",
    "left_hip": "mid_hip",
    "left_knee": "left_hip",
    "left_ankle": "left_knee",
    "right_eye": "nose",
    "left_eye": "nose",
    "right_ear": "right_eye",
    "left_ear": "left_eye",
    "left_big_toe": "left_ankle",
    "left_small_toe": "left_big_toe",
    "left_heel": "left_ankle",
    "right_big_toe": "right_ankle",
    "right_small_toe": "right_big_toe",
    "right_heel": "right_ankle"
}

# %%
# https://github.com/CMU-Perceptual-Computing-Lab/openpose/blob/master/doc/02_output.md

@dataclass
class PoseKeypoints:
    nose: Joint
    neck: Joint
    right_shoulder: Joint
    right_elbow: Joint
    right_wrist: Joint
    left_shoulder: Joint
    left_elbow: Joint
    left_wrist: Joint
    mid_hip: Joint
    right_hip: Joint
    right_knee: Joint
    right_ankle: Joint
    left_hip: Joint
    left_knee: Joint
    left_ankle: Joint
    right_eye: Joint
    left_eye: Joint
    right_ear: Joint
    left_ear: Joint
    left_big_toe: Joint
    left_small_toe: Joint
    left_heel: Joint
    right_big_toe: Joint
    right_small_toe: Joint
    right_heel: Joint
    
    def get_empty_joints(self):
        return {joint_name: getattr(self, joint_name) for joint_name in self.__annotations__.keys() if getattr(self, joint_name).is_empty()}
    
    def overlay_pose(self, frame):
        mapping = list(PoseKeypoints.__dict__["__annotations__"].keys())
        pose_overlayed_frame = frame.copy()
        height, width, channels = pose_overlayed_frame.shape

        for i, joint_name in enumerate(self.__annotations__.keys()):
            joint = getattr(self, joint_name)

            if joint.is_empty(): 
                continue
            
            joint_pos = (round(joint.x * width), round(joint.y * height))
            cv2.circle(pose_overlayed_frame, joint_pos, radius=1, color=joint_colours[i], thickness=2)
            cv2.putText(pose_overlayed_frame, mapping[i], (round(joint.x * width), round(joint.y * (height - 0.02))), cv2.FONT_HERSHEY_SIMPLEX, 0.5, joint_colours[i], 1, cv2.LINE_AA)
            
            if joint.parent is not None and not joint.parent.is_empty():
                parent_pos = (round(joint.parent.x * width), round(joint.parent.y * height))
                cv2.line(pose_overlayed_frame, joint_pos, parent_pos, joint_colours[i], thickness=1)
        
        return pose_overlayed_frame
    
    def head_visibility_score(self):
        # 0 = not visible, 1 = completely visible
        parts = {"nose", "left_eye", "left_ear", "right_eye", "right_ear"}
        empty_parts = set(self.get_empty_joints().keys())
        visible_parts = parts - empty_parts
        return len(visible_parts) / len(parts)
    
    def torso_arms_visibility_score(self):
        # 0 = not visible, 1 = completely visible
        parts = {"neck", "left_shoulder", "left_elbow", "left_wrist", "right_shoulder", "right_elbow", "right_wrist"}
        empty_parts = set(self.get_empty_joints().keys())
        visible_parts = parts - empty_parts
        return len(visible_parts) / len(parts)
    
    def hip_visibility_score(self):
        # 0 = not visible, 1 = completely visible
        parts = {"mid_hip", "left_hip", "right_hip"}
        empty_parts = set(self.get_empty_joints().keys())
        visible_parts = parts - empty_parts
        return len(visible_parts) / len(parts)
    
    def legs_visibility_score(self):
        # 0 = not visible, 1 = completely visible
        parts = {"left_knee", "left_ankle", "right_knee", "right_ankle"}
        empty_parts = set(self.get_empty_joints().keys())
        visible_parts = parts - empty_parts
        return len(visible_parts) / len(parts)
    
    def feet_visibility_score(self):
        # 0 = not visible, 1 = completely visible
        parts = {"left_ankle", "left_heel", "left_big_toe", "left_small_toe", "right_ankle", "right_heel", "right_big_toe", "right_small_toe"}
        empty_parts = set(self.get_empty_joints().keys())
        visible_parts = parts - empty_parts
        return len(visible_parts) / len(parts)
    
    def knee_angles(self):
        left_ratio = None
        right_ratio = None
        
        # we can estimate if someone is sitting by looking at the angle of their knee to the hip
        # note left_hip > left_knee but left_hip.y < left_knee.y due to the way coords are done in these images
        
        if not self.left_hip.is_empty() and not self.left_knee.is_empty():
            left_opp = -self.left_hip.y + self.left_knee.y
            left_adj = abs(self.left_hip.x - self.left_knee.x)
            
            left_ratio = np.rad2deg(np.arctan2(left_opp, left_adj))
            
        if not self.right_hip.is_empty() and not self.right_knee.is_empty():
            right_opp = -self.right_hip.y + self.right_knee.y
            right_adj = abs(self.right_hip.x - self.right_knee.x)
            
            right_ratio = np.rad2deg(np.arctan2(right_opp, right_adj))
        
        return left_ratio, right_ratio
    
    def classify_general_pose(self):
        head_score = self.head_visibility_score()
        ta_score = self.torso_arms_visibility_score()
        hip_score = self.hip_visibility_score()
        legs_score = self.legs_visibility_score()
        feet_score = self.feet_visibility_score()
        
        if head_score >= 0.6 and ta_score <= 0.45 and hip_score + legs_score + feet_score == 0:
            return "Head Only"
        
        # hip_score >= 0 redundant
        if head_score >= 0.4 and ta_score >= 0.5 and hip_score >= 0 and legs_score + feet_score == 0: 
            return "Half Body"
        
        # feet_score >= 0 redundant
        if head_score >= 0.4 and ta_score >= 0.7 and hip_score >= 0.5 and legs_score >= 0.5 and feet_score >= 0:
            return "Full Body"
        
        return "Other"
        
    def is_sitting(self):
        left_angle, right_angle = self.knee_angles()
        
        if left_angle is None and right_angle is None:
            return "Other"
        
        if left_angle is not None:
            if left_angle < 0:
                return "Other"
        
        if right_angle is not None:
            if right_angle < 0:
                return "Other"
            
        angle_threshold = 50
        
        left_sitting = None if left_angle is None else left_angle < angle_threshold
        right_sitting = None if right_angle is None else right_angle < angle_threshold
        
        if left_sitting is not None and right_sitting is not None:
            # As long as one says they are sitting, we take it to be that they are sitting
            return "Sitting" if left_sitting or right_sitting else "Standing"
        
        if left_sitting is not None:
            return "Sitting" if left_sitting else "Standing"
        
        if right_sitting is not None:
            return "Sitting" if right_sitting else "Standing"
    
    def classify(self):
        general_pose = self.classify_general_pose()
        
        if general_pose != "Full Body":
            return general_pose
        
        position = self.is_sitting()
        
        if position == "Other":
            return "Other"
        
        return f"Full Body {position}"
    
    @staticmethod
    def load_keypoints(raw_kps):
        mapping = list(PoseKeypoints.__dict__["__annotations__"].keys())
        points_as_dict = {}
        
        for i, part in enumerate(mapping):
            if joint_connections[part] is None:
                points_as_dict[part] = Joint(None, raw_kps[3 * i], raw_kps[3 * i + 1], raw_kps[3 * i + 2])
            else:
                points_as_dict[part] = Joint(points_as_dict[joint_connections[part]], raw_kps[3 * i], raw_kps[3 * i + 1], raw_kps[3 * i + 2])
        
        return PoseKeypoints(**points_as_dict)

# %%
in_frame_folder = "./output/segmented/Train/Movie"
in_pose_folder = "./output/segmented/Train/Movie/openpose_out_normalised"
out_folder = "./output/pose_classified_movie"

# %%
file_names = []

for file in os.listdir(in_frame_folder):
    path = f"{in_frame_folder}/{file}"
    
    if not os.path.isfile(path):
        continue
        
    file_names.append(''.join(file.split(".")[:-1]))

len(file_names)
# Out:
# 5887

# %%
for file in file_names:
    frame_loc = f"{in_frame_folder}/{file}.jpg"
    keypoints_loc = f"{in_pose_folder}/{file}_keypoints.json"
    
    with open(keypoints_loc, "r") as fp:
        raw_data = json.load(fp)
    
    if len(raw_data["people"]) != 1:
        # print(frame_loc)
        continue
    
    print(frame_loc)
    
    kps = raw_data["people"][0]["pose_keypoints_2d"]
    pose = PoseKeypoints.load_keypoints(kps)
    
    classification = pose.classify()
    save_loc = f"{out_folder}/{classification}/{file}.jpg"
    
    in_frame = cv2.imread(frame_loc)
    out_frame = pose.overlay_pose(in_frame)
    
    print(classification)
    
    cv2.imwrite(save_loc, out_frame)
# Out:
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00034_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00034_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00035_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00035_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00036_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00036_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00037_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00037_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00038_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00038_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00039_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00039_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00040_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00040_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00041_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00041_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00042_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00042_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00043_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00043_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00043_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00044_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00044_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00045_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00045_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00046_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00046_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00047_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00047_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00048_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00049_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00049_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00049_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00050_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00051_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00051_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00052_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00052_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00053_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00053_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00054_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00054_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00055_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00055_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00056_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00056_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00057_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00057_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00058_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00058_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00059_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00059_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00060_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00060_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00061_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00061_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00062_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00062_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00063_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00063_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00064_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00064_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00065_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00065_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00066_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00066_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00067_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00067_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00068_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00068_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00069_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00069_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00070_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00070_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00070_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00071_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00071_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00072_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00073_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00073_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00074_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00074_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00075_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00075_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00076_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00076_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00077_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00077_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00078_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00079_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00080_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00080_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00081_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00082_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00082_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00083_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00083_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00084_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00084_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00085_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00085_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00086_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00086_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00087_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00087_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00088_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00089_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00089_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00090_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00090_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00091_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00091_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00092_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00092_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00093_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00093_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00094_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00094_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00095_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00095_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00096_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00096_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00097_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00097_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00098_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00098_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00099_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00099_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00100_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00100_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00101_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00101_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00102_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00102_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00103_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00104_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00105_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00106_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00106_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00107_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00108_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00109_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00109_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00110_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00111_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00112_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00113_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00113_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00114_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00115_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00116_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00117_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00118_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00119_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00119_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00120_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00120_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00121_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00121_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00122_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00123_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00123_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00124_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00128_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00128_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00129_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00130_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00131_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00131_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00132_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00132_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00133_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00133_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00134_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00134_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00135_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00135_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00136_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00136_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00137_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00137_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00137_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00138_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00138_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00138_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00139_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00139_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00140_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00140_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00141_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00141_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00142_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00142_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00143_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00144_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00144_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00145_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00145_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00146_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00146_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00147_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00147_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00148_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00149_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00149_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00150_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00150_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00151_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00153_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00154_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00154_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00155_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00155_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00155_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00156_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00156_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00157_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00157_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00158_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00158_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00159_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00159_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00159_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00160_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00160_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00161_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00161_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00161_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00162_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00162_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00162_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00163_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00163_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00163_4.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00164_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00164_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00165_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00165_2.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00166_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00167_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00168_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00168_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00170_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00171_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00175_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00176_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00177_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00179_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00180_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00181_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00181_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00182_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00184_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00186_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00187_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00187_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00188_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00191_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00191_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00192_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00193_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00195_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00195_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00197_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00199_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00199_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00200_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00201_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00202_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00203_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00203_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00204_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00204_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00205_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00205_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00206_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00207_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00208_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00208_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00210_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00212_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00214_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00215_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00216_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00216_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00217_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00220_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00223_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00234_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00240_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00241_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00246_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00247_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00248_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00249_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00250_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00251_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00252_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00253_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00254_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00255_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00258_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00259_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00260_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00261_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00261_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00262_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00262_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00263_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00264_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00264_2.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00265_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00265_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00266_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00266_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00266_2.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00268_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00268_2.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00269_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00269_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00270_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00271_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00271_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00272_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00273_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00273_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00275_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00276_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00276_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00277_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00278_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00279_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00280_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00281_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00281_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00284_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00285_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00286_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00287_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00288_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00290_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00292_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00295_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00296_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00298_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00300_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00301_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00302_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00304_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00305_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00306_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00307_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00308_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00309_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00310_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00311_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00312_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00313_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00314_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00315_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00316_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00317_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00318_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00354_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00355_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00389_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00397_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00400_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00401_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00402_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00403_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00404_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00405_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00405_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00406_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00406_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00407_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00407_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00408_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00408_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00409_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00410_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00410_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00411_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00411_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00412_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00413_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00414_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00415_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00416_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00417_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00418_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00419_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00420_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00421_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00422_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00423_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00424_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00425_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00426_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00427_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00427_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00428_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00429_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00429_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00430_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00431_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00432_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00433_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00434_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00435_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00436_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00437_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00440_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00441_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00446_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00447_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00447_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00449_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00450_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00451_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00452_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00668_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00669_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00669_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00670_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00670_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00671_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00672_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00672_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00673_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00673_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00673_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00674_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00674_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00675_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00675_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00676_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00677_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00681_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00682_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00683_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00684_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00685_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00686_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00687_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00688_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00690_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00693_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00694_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00694_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00695_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00696_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00697_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00697_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00698_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00698_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00699_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00699_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00700_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00700_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00701_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00701_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00702_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00703_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00703_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00704_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00704_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00705_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00705_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00706_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00706_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00707_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00707_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00708_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00708_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00709_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00710_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00710_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00711_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00712_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00712_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00713_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00713_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00714_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00715_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00716_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00716_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00717_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00717_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00718_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00718_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00719_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00719_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00720_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00720_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00721_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00721_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00721_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00722_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00722_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00722_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00723_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00723_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00724_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00725_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00727_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00728_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00733_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00733_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00734_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00734_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00735_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00735_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00736_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00736_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00737_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00737_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00738_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00738_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00739_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00739_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00740_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00740_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00741_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00741_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00742_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00743_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00743_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00744_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00744_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00745_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00745_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00746_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00746_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00747_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00747_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00748_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00748_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00749_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00749_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00750_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00750_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00751_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00751_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00752_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00752_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00753_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00753_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00754_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00755_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00755_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00756_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00756_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00757_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00757_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00758_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00758_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00759_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00759_3.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00760_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00761_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00762_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00763_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00765_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00767_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00768_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00769_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00770_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00770_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00771_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00771_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00772_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00773_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00773_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00774_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00774_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00775_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00775_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00776_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00776_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00777_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00778_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00778_3.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00779_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00779_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00780_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00780_2.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00781_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00781_2.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00782_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00782_1.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00783_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00784_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00785_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00786_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00787_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00788_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00789_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00790_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00791_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00792_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00793_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00794_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00795_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00796_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00797_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00798_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00799_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00800_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00801_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00802_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00803_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00804_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00805_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00807_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_01_00808_0.jpg
# Half Body
# ...
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02189_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02190_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02191_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02192_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02193_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02194_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02195_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02196_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02197_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02198_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02199_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02200_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02201_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02202_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02203_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02204_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02205_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02206_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02208_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02209_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02210_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02211_0.jpg
# Full Body Standing
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02214_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02217_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02219_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02221_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02245_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02247_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02254_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02255_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02256_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02257_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02262_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02263_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02264_1.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02265_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02266_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02267_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02268_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02269_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02270_1.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02271_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02272_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02273_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02274_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02275_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02276_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02277_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02278_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02279_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02280_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02281_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02282_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02283_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02284_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02285_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02286_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02287_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02288_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02289_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02290_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02291_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02292_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02293_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02294_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02295_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02296_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02297_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02298_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02299_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02300_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02301_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02302_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02303_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02304_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02305_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02306_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02307_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02308_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02309_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02310_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02311_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02312_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02313_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02314_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02315_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02316_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02317_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02318_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02319_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02320_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02322_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02323_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02324_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02325_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02326_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02327_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02328_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02329_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02330_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02331_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02332_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02333_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02334_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02335_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02336_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02337_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02338_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02339_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02340_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02341_0.jpg
# Other
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02342_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02343_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02345_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02346_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02347_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02348_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02349_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02350_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02351_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02352_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02353_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02354_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02355_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02356_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02357_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02358_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02359_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02360_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02361_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02362_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02363_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02364_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02365_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02366_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02373_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02374_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02375_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02376_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02377_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02378_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02379_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02380_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02381_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02382_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02383_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02384_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02385_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02565_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02566_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02567_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02568_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02569_0.jpg
# Head Only
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02570_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02571_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02572_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02573_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02574_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02575_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02576_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02577_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02578_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02579_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02580_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02581_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02582_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02583_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02584_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02585_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02586_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02587_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02588_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02589_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02590_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02591_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02592_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02593_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02594_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02595_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02596_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02597_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02598_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02599_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02600_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02601_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02602_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02603_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02604_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02605_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02606_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02607_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02608_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02609_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02610_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02611_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02612_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02613_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02614_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02615_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02616_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02617_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02618_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02619_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02620_0.jpg
# Half Body
# ./output/segmented/Train/Movie/Segmented_Train_Movie_03_02621_0.jpg
# Half Body
